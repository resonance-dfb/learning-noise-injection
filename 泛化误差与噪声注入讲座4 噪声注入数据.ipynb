# %%
import random
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import pandas as pd
#import imageio
import numpy as np
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.utils.data as Data

import matplotlib.pyplot as plt
# %matplotlib inline
import math

SEED = 1234#固定种子，大家都可以重复结果
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED) 
torch.backends.cudnn.deterministic = True

x = torch.unsqueeze(torch.linspace(-1, 1, 21), dim=1)
ytrain = torch.sin(math.pi*x) + 0.2*torch.randn(x.size())  # 这里是污染数据固定不变当成训练数据

#噪声注入输入数据方法
#对于训练数据ytrain
epoch = 20000 #一次训练步长数目
NJnum=30 #对于每个注入噪声强度sigma，仿真次数为NJnum

# %%
class Net(torch.nn.Module):  # 定义网络
    def __init__(self, n_feature, n_hidden1, n_output):
        super(Net, self).__init__()
        self.hidden1 = torch.nn.Linear(n_feature, n_hidden1)  # 全连接层
        self.predict = torch.nn.Linear(n_hidden1, n_output)   # 输出层

    def forward(self, x):
        x = self.hidden1(x)
        x = torch.sigmoid(x)
        x = self.predict(x)  # 前向传播过程
        return x  

    def reset_parameters(self):
        # 重新初始化网络参数
        self.hidden1.reset_parameters()
        self.predict.reset_parameters()
#经典的sigmoid神经网络1*n_hidden1*1，中间隐层为sigmoid函数
#这里把Net Class放在循环外面，对于不同的噪声注入数据，采用net.reset_parameters()对于网络进行重置

net = Net(n_feature=1, n_hidden1=10, n_output=1)#定义1*10*1的网络
device = torch.device('cpu')#cpu计算
optimizer = torch.optim.Adam(net.parameters(), lr=0.01,betas=(0.96,0.96))
#Adam算法，学习率是固定的0.01，矩参数是0.96
loss_func = torch.nn.MSELoss().to(device)  # loss函数是均方误差mse

# %%
from tqdm import tqdm#载入进度条显示包

sigma = 10**(-3)#人工选择加入噪声均方根为0.001

inputx = torch.unsqueeze(torch.linspace(-1, 1, 401), dim=1)
output = torch.zeros(inputx.shape).to(device)#这里用这个变量存储每次网络被训练时输出

for num in range(NJnum):
    
    SEED = 1234 + 12 * num  # 改变种子，模仿每次独立同分布的噪声添加噪声
    
    np.random.seed(SEED)
    random.seed(SEED) 
    
    # Generate noisy data for each iteration
    x_noisy = x + sigma * torch.randn(x.size()).to(device) #把噪声加入输入数据
    ytrain = ytrain.to(device)#y相当于标签保持不变
    
    #x = x.to(device)#把噪声加入标签,x保持不变
    #y_noisy = ytrain + sigma * torch.randn(x.size()).to(device) #把噪声加入标签
    
    
    progress_bar = tqdm(range(epoch), desc=f'NJnum {num}/{NJnum}')  # Create progress bar
    net.reset_parameters()
    for t in progress_bar:
        prediction = net(x_noisy)
        loss = loss_func(prediction, ytrain)

        #prediction = net(x)
        #loss = loss_func(prediction, y_noisy)
            
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update progress bar description every 100 epochs
        if t % 200 == 0:
            progress_bar.set_postfix({'loss': loss.item()})
    
    # Accumulate the output of each training
    response = net(inputx)#每次NJnum训练的网络对于inputx的响应
    output += response#NJnum次的网络输出迭加

#NJnum次的网络输出平均输出
output /= NJnum
# Out:
# NJnum 0/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1890.77it/s, loss=0.00191]
# NJnum 1/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1977.23it/s, loss=0.0032]
# NJnum 2/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:09<00:00, 2000.93it/s, loss=0.00107]
# NJnum 3/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:09<00:00, 2035.90it/s, loss=0.00188]
# NJnum 4/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1984.75it/s, loss=0.00197]
# NJnum 5/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1997.07it/s, loss=0.0189]
# NJnum 6/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:09<00:00, 2001.85it/s, loss=0.00202]
# NJnum 7/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1974.87it/s, loss=0.000942]
# NJnum 8/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1990.21it/s, loss=0.00935]
# NJnum 9/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1968.62it/s, loss=7.63e-5]
# NJnum 10/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1987.04it/s, loss=0.00118]
# NJnum 11/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:09<00:00, 2010.77it/s, loss=0.0206]
# NJnum 12/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1935.71it/s, loss=0.0188]
# NJnum 13/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1972.01it/s, loss=0.000848]
# NJnum 14/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:09<00:00, 2003.61it/s, loss=0.00128]
# NJnum 15/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1955.88it/s, loss=0.00262]
# NJnum 16/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1928.15it/s, loss=0.0158]
# NJnum 17/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1936.77it/s, loss=0.00272]
# NJnum 18/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1946.88it/s, loss=0.00256]
# NJnum 19/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1976.39it/s, loss=0.00117]
# NJnum 20/30: 100%|██████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1909.55it/s, loss=0.02]
# NJnum 21/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1937.13it/s, loss=0.00913]
# NJnum 22/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1940.80it/s, loss=0.0201]
# NJnum 23/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1744.53it/s, loss=0.00853]
# NJnum 24/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1766.70it/s, loss=0.00194]
# NJnum 25/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1914.22it/s, loss=0.000957]
# NJnum 26/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1899.76it/s, loss=0.000821]
# NJnum 27/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1941.04it/s, loss=0.000961]
# NJnum 28/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1901.61it/s, loss=0.00113]
# NJnum 29/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1902.32it/s, loss=0.0116]

# %%
#画出网络学习曲线
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams ['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus']=False  # #用来正常显示负号
#plt.style.use(['science','ieee'])#如果找不到science plot包则载入这句话
fig, ax = plt.subplots(figsize=(5,4)) 
plt.cla()
plt.tick_params(labelsize=15)
ax.set_xlabel('x', fontsize=15)
ax.set_ylabel('y', fontsize=15, labelpad = -1)
ax.set_xlim(-1.1, 1.1)
ax.set_ylim(-1.5, 1.5)
# 画出训练集来，是橘色的散点。
ax.scatter(x.data.numpy(), ytrain.data.numpy(), color="orange")
# NJnum次网络输出平均，因为x加入了NJnum次噪声进行了扰动
ax.plot(inputx.data.numpy(), output.data.numpy(), 'g-', lw=2)
#真实信号
signal = torch.sin(math.pi*inputx)
ax.plot(inputx.data.numpy(), signal.data.numpy(), 'r--', lw=1,label='signal')

# %%
####来一组继续测试
SEED = 666

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED) 
torch.backends.cudnn.deterministic = True
xtest = torch.unsqueeze(torch.linspace(-1, 1, 41), dim=1)
ytest = torch.sin(math.pi*xtest) + 0.2*torch.randn(xtest.size())
prediction3_subset = output[::10]
loss3 = loss_func(prediction3_subset, ytest) # 计算loss，通过prediction和y的差来计算mse
print(loss3.data)# 大约是10^{-2}次级别，与拟合的误差相比，泛化误差非常大，相差2个数量级
# Out:
# tensor(0.0526)

# %%
#上面从拟合曲线可以看出，加入sigma=10^{-3}大小的拟合曲线还是过拟合，loss0.001~0.02之间（进度条处），与测试0.0525还是有差距

# %%
#我们继续增加sigma值，试试效果
from tqdm import tqdm

sigma = 10**(-2)  # 人工选择加入噪声均方根为0.01
losses = []  # 用于存储每次训练的损失

inputx = torch.unsqueeze(torch.linspace(-1, 1, 401), dim=1)
output = torch.zeros(inputx.shape).to(device)

for num in range(NJnum):
    
    SEED = 1234 + 12 * num  
    np.random.seed(SEED)
    random.seed(SEED) 
    
    x_noisy = x + sigma * torch.randn(x.size()).to(device)
    ytrain = ytrain.to(device)
    
    progress_bar = tqdm(range(epoch), desc=f'NJnum {num}/{NJnum}')
    net.reset_parameters()
    for t in progress_bar:
        prediction = net(x_noisy)
        loss = loss_func(prediction, ytrain)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        losses.append(loss.item())  # 记录每次训练的损失
        
        if t % 200 == 0:
            progress_bar.set_postfix({'loss': loss.item()})
    
    response = net(inputx)
    output += response

# 平均损失
average_loss = sum(losses) / len(losses)
#平均网络输出
output /= NJnum
# Out:
# NJnum 0/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1976.83it/s, loss=0.00127]
# NJnum 1/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1942.88it/s, loss=0.000609]
# NJnum 2/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1913.71it/s, loss=0.000754]
# NJnum 3/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1965.35it/s, loss=0.00733]
# NJnum 4/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1978.81it/s, loss=0.00116]
# NJnum 5/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1951.65it/s, loss=0.00132]
# NJnum 6/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1920.41it/s, loss=0.0203]
# NJnum 7/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1933.94it/s, loss=0.00232]
# NJnum 8/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1894.82it/s, loss=0.00322]
# NJnum 9/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1673.44it/s, loss=0.0199]
# NJnum 10/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1783.08it/s, loss=0.00434]
# NJnum 11/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1878.13it/s, loss=0.00199]
# NJnum 12/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1891.96it/s, loss=0.00244]
# NJnum 13/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1880.03it/s, loss=0.00422]
# NJnum 14/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1873.24it/s, loss=0.0218]
# NJnum 15/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1888.67it/s, loss=0.0183]
# NJnum 16/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1889.41it/s, loss=0.000918]
# NJnum 17/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1873.58it/s, loss=0.00188]
# NJnum 18/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1892.22it/s, loss=0.000899]
# NJnum 19/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1834.18it/s, loss=0.0203]
# NJnum 20/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1843.33it/s, loss=0.000215]
# NJnum 21/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1821.14it/s, loss=0.00134]
# NJnum 22/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1746.19it/s, loss=0.019]
# NJnum 23/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1854.70it/s, loss=0.00147]
# NJnum 24/30: 100%|██████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1862.99it/s, loss=0.000827]
# NJnum 25/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1853.13it/s, loss=0.00112]
# NJnum 26/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1829.06it/s, loss=0.00528]
# NJnum 27/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1850.08it/s, loss=0.00106]
# NJnum 28/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1854.55it/s, loss=0.00286]
# NJnum 29/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1868.96it/s, loss=0.00155]

# %%
average_loss
# Out:
# 0.018354569629671434

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams ['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus']=False  # #用来正常显示负号
#plt.style.use(['science','ieee'])#如果找不到science plot包则载入这句话
fig, ax = plt.subplots(figsize=(5,4)) 
plt.cla()
plt.tick_params(labelsize=15)
ax.set_xlabel('x', fontsize=15)
ax.set_ylabel('y', fontsize=15, labelpad = -1)
ax.set_xlim(-1.1, 1.1)
ax.set_ylim(-1.5, 1.5)
# 画出训练集来，是橘色的散点。
ax.scatter(x.data.numpy(), ytrain.data.numpy(), color="orange")
# NJnum次网络输出平均，因为x加入了NJnum次噪声进行了扰动
ax.plot(inputx.data.numpy(), output.data.numpy(), 'g-', lw=2)
#真实信号
signal = torch.sin(math.pi*inputx)
ax.plot(inputx.data.numpy(), signal.data.numpy(), 'r--', lw=1,label='signal')

# %%
####来一组继续测试
SEED = 666

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED) 
torch.backends.cudnn.deterministic = True
xtest = torch.unsqueeze(torch.linspace(-1, 1, 41), dim=1)
ytest = torch.sin(math.pi*xtest) + 0.2*torch.randn(xtest.size())
prediction3_subset = output[::10]
loss3 = loss_func(prediction3_subset, ytest) # 计算loss，通过prediction和y的差来计算mse
print(loss3.data)# 大约是10^{-2}次级别，与拟合的误差相比，泛化误差非常大，相差2个数量级
# Out:
# tensor(0.0538)

# %%
#sigma=0.01也不好，loss开始增大，测试是0.0538

# %%
#继续增大sigma
from tqdm import tqdm

sigma = 0.1  # 人工选择加入噪声均方根为0.01
losses = []  # 用于存储每次训练的损失

inputx = torch.unsqueeze(torch.linspace(-1, 1, 401), dim=1)
output = torch.zeros(inputx.shape).to(device)

for num in range(NJnum):
    
    SEED = 1234 + 12 * num  
    np.random.seed(SEED)
    random.seed(SEED) 
    
    x_noisy = x + sigma * torch.randn(x.size()).to(device)
    ytrain = ytrain.to(device)
    
    progress_bar = tqdm(range(epoch), desc=f'NJnum {num}/{NJnum}')
    net.reset_parameters()
    for t in progress_bar:
        prediction = net(x_noisy)
        loss = loss_func(prediction, ytrain)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        losses.append(loss.item())  # 记录每次训练的损失
        
        if t % 200 == 0:
            progress_bar.set_postfix({'loss': loss.item()})
    
    response = net(inputx)
    output += response

# 平均损失
average_loss = sum(losses) / len(losses)
print(average_loss)
#平均网络输出
output /= NJnum
# Out:
# NJnum 0/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1959.92it/s, loss=0.0369]
# NJnum 1/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1961.53it/s, loss=0.00929]
# NJnum 2/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1973.38it/s, loss=0.00849]
# NJnum 3/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1944.52it/s, loss=0.000978]
# NJnum 4/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1947.54it/s, loss=0.00949]
# NJnum 5/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1947.06it/s, loss=0.00933]
# NJnum 6/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1931.86it/s, loss=0.00368]
# NJnum 7/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1933.61it/s, loss=0.0117]
# NJnum 8/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1897.32it/s, loss=0.00758]
# NJnum 9/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1892.56it/s, loss=0.0219]
# NJnum 10/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1900.18it/s, loss=0.0394]
# NJnum 11/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1867.78it/s, loss=0.022]
# NJnum 12/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1826.93it/s, loss=0.018]
# NJnum 13/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1888.67it/s, loss=0.0272]
# NJnum 14/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1879.72it/s, loss=0.00987]
# NJnum 15/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1852.16it/s, loss=0.00196]
# NJnum 16/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1881.57it/s, loss=0.0165]
# NJnum 17/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1858.02it/s, loss=0.014]
# NJnum 18/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1867.20it/s, loss=0.00684]
# NJnum 19/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1862.38it/s, loss=0.00962]
# NJnum 20/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1882.64it/s, loss=0.00379]
# NJnum 21/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1869.62it/s, loss=0.00762]
# NJnum 22/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1734.64it/s, loss=0.0124]
# NJnum 23/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:26<00:00, 744.44it/s, loss=0.0127]
# NJnum 24/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:21<00:00, 946.74it/s, loss=0.0537]
# NJnum 25/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:14<00:00, 1402.54it/s, loss=0.00335]
# NJnum 26/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1784.44it/s, loss=0.00723]
# NJnum 27/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1792.52it/s, loss=0.00992]
# NJnum 28/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1785.84it/s, loss=0.0164]
# NJnum 29/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1790.83it/s, loss=0.00395]
# 0.02894052441661033

# %%
average_loss
# Out:
# 0.02894052441661033

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams ['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus']=False  # #用来正常显示负号
#plt.style.use(['science','ieee'])#如果找不到science plot包则载入这句话
fig, ax = plt.subplots(figsize=(5,4)) 
plt.cla()
plt.tick_params(labelsize=15)
ax.set_xlabel('x', fontsize=15)
ax.set_ylabel('y', fontsize=15, labelpad = -1)
ax.set_xlim(-1.1, 1.1)
ax.set_ylim(-1.5, 1.5)
# 画出训练集来，是橘色的散点。
ax.scatter(x.data.numpy(), ytrain.data.numpy(), color="orange")
# NJnum次网络输出平均，因为x加入了NJnum次噪声进行了扰动
ax.plot(inputx.data.numpy(), output.data.numpy(), 'g-', lw=2)
#真实信号
signal = torch.sin(math.pi*inputx)
ax.plot(inputx.data.numpy(), signal.data.numpy(), 'r--', lw=1,label='signal')

# %%
#开始改善了

# %%
####来一组继续测试
SEED = 666

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED) 
torch.backends.cudnn.deterministic = True
xtest = torch.unsqueeze(torch.linspace(-1, 1, 41), dim=1)
ytest = torch.sin(math.pi*xtest) + 0.2*torch.randn(xtest.size())
prediction3_subset = output[::10]
loss3 = loss_func(prediction3_subset, ytest) # 计算loss，通过prediction和y的差来计算mse
print(loss3.data)# 大约是10^{-2}次级别，与拟合的误差相比，泛化误差非常大，相差2个数量级
# Out:
# tensor(0.0572)

# %%
#loss 0.0289，测试0.0572开始接近了，泛化误差改善了

# %%
#继续改变sigma的大小，可以看出这种人工寻找的方式是计算量很大的，并且不知道最优值sigma是多少

# %%
#继续增大sigma
from tqdm import tqdm

sigma = 0.5  # 人工选择加入噪声均方根为0.01
losses = []  # 用于存储每次训练的损失

inputx = torch.unsqueeze(torch.linspace(-1, 1, 401), dim=1)
output = torch.zeros(inputx.shape).to(device)

for num in range(NJnum):
    
    SEED = 1234 + 12 * num  
    np.random.seed(SEED)
    random.seed(SEED) 
    
    x_noisy = x + sigma * torch.randn(x.size()).to(device)
    ytrain = ytrain.to(device)
    
    progress_bar = tqdm(range(epoch), desc=f'NJnum {num}/{NJnum}')
    net.reset_parameters()
    for t in progress_bar:
        prediction = net(x_noisy)
        loss = loss_func(prediction, ytrain)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        losses.append(loss.item())  # 记录每次训练的损失
        
        if t % 200 == 0:
            progress_bar.set_postfix({'loss': loss.item()})
    
    response = net(inputx)
    output += response

# 平均损失
average_loss = sum(losses) / len(losses)
print("average_loss =", average_loss)
#平均网络输出
output /= NJnum
# Out:
# NJnum 0/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1944.75it/s, loss=0.0533]
# NJnum 1/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1939.14it/s, loss=0.0295]
# NJnum 2/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1936.86it/s, loss=0.0167]
# NJnum 3/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1913.68it/s, loss=0.0206]
# NJnum 4/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1917.79it/s, loss=0.0069]
# NJnum 5/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1901.55it/s, loss=0.0203]
# NJnum 6/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1911.12it/s, loss=0.0269]
# NJnum 7/30: 100%|██████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1881.25it/s, loss=0.013]
# NJnum 8/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1852.16it/s, loss=0.0274]
# NJnum 9/30: 100%|███████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1879.05it/s, loss=0.21]
# NJnum 10/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1878.83it/s, loss=0.0722]
# NJnum 11/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1844.10it/s, loss=0.271]
# NJnum 12/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1869.29it/s, loss=0.0407]
# NJnum 13/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1845.59it/s, loss=0.00262]
# NJnum 14/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1866.01it/s, loss=0.0117]
# NJnum 15/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1852.16it/s, loss=0.0292]
# NJnum 16/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1844.45it/s, loss=0.0281]
# NJnum 17/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1842.39it/s, loss=0.0262]
# NJnum 18/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1760.68it/s, loss=0.0237]
# NJnum 19/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1782.06it/s, loss=0.115]
# NJnum 20/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1842.14it/s, loss=0.0601]
# NJnum 21/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:10<00:00, 1819.98it/s, loss=0.243]
# NJnum 22/30: 100%|█████████████████████████████████████████████████| 20000/20000 [00:13<00:00, 1450.12it/s, loss=0.162]
# NJnum 23/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:16<00:00, 1196.34it/s, loss=0.00275]
# NJnum 24/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:16<00:00, 1237.37it/s, loss=0.0479]
# NJnum 25/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:16<00:00, 1203.81it/s, loss=0.0525]
# NJnum 26/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:14<00:00, 1353.38it/s, loss=0.0227]
# NJnum 27/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1737.53it/s, loss=0.0471]
# NJnum 28/30: 100%|███████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1730.25it/s, loss=0.00221]
# NJnum 29/30: 100%|████████████████████████████████████████████████| 20000/20000 [00:11<00:00, 1782.65it/s, loss=0.0302]
# average_loss = 0.0972439398689797

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams ['font.serif'] = ['Times New Roman']
mpl.rcParams['figure.dpi'] = 800
mpl.rcParams['axes.unicode_minus']=False  # #用来正常显示负号
#plt.style.use(['science','ieee'])#如果找不到science plot包则载入这句话
fig, ax = plt.subplots(figsize=(5,4)) 
plt.cla()
plt.tick_params(labelsize=15)
ax.set_xlabel('x', fontsize=15)
ax.set_ylabel('y', fontsize=15, labelpad = -1)
ax.set_xlim(-1.1, 1.1)
ax.set_ylim(-1.5, 1.5)
# 画出训练集来，是橘色的散点。
ax.scatter(x.data.numpy(), ytrain.data.numpy(), color="orange")
# NJnum次网络输出平均，因为x加入了NJnum次噪声进行了扰动
ax.plot(inputx.data.numpy(), output.data.numpy(), 'g-', lw=2)
#真实信号
signal = torch.sin(math.pi*inputx)
ax.plot(inputx.data.numpy(), signal.data.numpy(), 'r--', lw=1,label='signal')

# %%
#噪声加大了，拟合曲线完全失控！
####来一组继续测试
SEED = 666

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED) 
torch.backends.cudnn.deterministic = True
xtest = torch.unsqueeze(torch.linspace(-1, 1, 41), dim=1)
ytest = torch.sin(math.pi*xtest) + 0.2*torch.randn(xtest.size())
prediction3_subset = output[::10]
loss3 = loss_func(prediction3_subset, ytest) # 计算loss，通过prediction和y的差来计算mse
print(loss3.data)# 大约是10^{-2}次级别，与拟合的误差相比，泛化误差非常大，相差2个数量级
# Out:
# tensor(0.3044)

# %%
#测试误差急剧增加！因此，最优的噪声应该在0.1左右，huo'z
