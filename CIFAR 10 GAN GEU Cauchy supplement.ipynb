# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, utils
import os
import numpy as np
from torch.utils.data import DataLoader, Dataset
from torch.nn.functional import sigmoid, interpolate
from torchvision.models import inception_v3
from scipy import linalg
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt

# 检查已下载的文件
cache_dir = os.path.expanduser("~/.cache/torch/hub/checkpoints/")
pytorch_fid_file = os.path.join(cache_dir, "pt_inception-2015-12-05-6726825d.pth")
torch_fidelity_file = os.path.join(cache_dir, "weights-inception-2015-12-05-6726825d.pth")

print("检查已下载的模型文件...")
pytorch_fid_exists = os.path.exists(pytorch_fid_file)
torch_fidelity_exists = os.path.exists(torch_fidelity_file)

if pytorch_fid_exists:
    size_mb = os.path.getsize(pytorch_fid_file) / 1024 / 1024
    print(f"pytorch-fid文件存在: {size_mb:.1f} MB")
else:
    print("pytorch-fid文件不存在")

if torch_fidelity_exists:
    size_mb = os.path.getsize(torch_fidelity_file) / 1024 / 1024
    print(f"torch-fidelity文件存在: {size_mb:.1f} MB")
else:
    print("torch-fidelity文件不存在")

# 使用专业的FID和IS计算包 - 直接尝试使用，不预先检查文件完整性
try:
    from pytorch_fid import fid_score
    from pytorch_fid.inception import InceptionV3
    PYTORCH_FID_AVAILABLE = pytorch_fid_exists  # 只要文件存在就尝试使用
    print(f"pytorch-fid 状态: {'可用' if PYTORCH_FID_AVAILABLE else '不可用'}")
except ImportError:
    PYTORCH_FID_AVAILABLE = False
    print("pytorch-fid 包未安装")

try:
    from torchmetrics.image.fid import FrechetInceptionDistance
    from torchmetrics.image.inception import InceptionScore
    TORCHMETRICS_AVAILABLE = torch_fidelity_exists  # 只要文件存在就尝试使用
    print(f"torchmetrics 状态: {'可用' if TORCHMETRICS_AVAILABLE else '不可用'}")
except ImportError:
    TORCHMETRICS_AVAILABLE = False
    print("torchmetrics 包未安装")

# 修改基础路径
BASE_PATH = "D:/PRE2023 2025"

# -------------------------------
# 1. Activation Function: Vsig
# -------------------------------
class Vsig(nn.Module):
    def __init__(self):
        super(Vsig, self).__init__()

    def forward(self, input):
        output = (1 + torch.erf(input / torch.sqrt(torch.tensor(2.0)))) / 2
        return output

# -------------------------------
# 2. CIFAR-10 Generator & Discriminator
# -------------------------------
class CIFAR10Generator(nn.Module):
    def __init__(self, latent_dim=100, ngf=64):
        super().__init__()
        self.latent_dim = latent_dim
        
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 2, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        return self.main(z.view(z.size(0), z.size(1), 1, 1))

class CIFAR10Discriminator(nn.Module):
    def __init__(self, use_vsig=False, ndf=64):
        super().__init__()
        self.use_vsig = use_vsig
        
        self.main = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 4, 1, 4, 1, 0, bias=False),
        )
        
        self.activation = Vsig() if use_vsig else nn.Sigmoid()

    def forward(self, x):
        logits = self.main(x)
        return self.activation(logits.view(-1, 1))

# -------------------------------
# 3. Training Function (修改版本 - 记录sigma值)
# -------------------------------
def train_cifar10_gan(epochs=50, use_vsig=False, model_name="sigmoid", batch_size=128):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    generator = CIFAR10Generator().to(device)
    discriminator = CIFAR10Discriminator(use_vsig).to(device)
    
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
            nn.init.normal_(m.weight.data, 1.0, 0.02)
            nn.init.constant_(m.bias.data, 0)
    
    generator.apply(weights_init)
    discriminator.apply(weights_init)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    dataset = datasets.CIFAR10("./data", download=True, train=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)

    lr = 0.0002
    beta1 = 0.5
    opt_G = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, 0.999))
    opt_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

    loss_fn = nn.BCELoss()
    
    G_losses = []
    D_losses = []
    sigma_values = []  # 新增：记录sigma值

    print(f"开始训练 {model_name} 模型...")
    
    for epoch in range(epochs):
        epoch_d_loss = 0
        epoch_g_loss = 0
        num_batches = 0
        
        for i, (real_imgs, _) in enumerate(dataloader):
            real_imgs = real_imgs.to(device)
            batch_size_current = real_imgs.size(0)

            real_labels = torch.ones(batch_size_current, 1).to(device) * 0.9
            fake_labels = torch.zeros(batch_size_current, 1).to(device) + 0.1

            # 更新判别器
            discriminator.zero_grad()
            
            real_output = discriminator(real_imgs)
            d_loss_real = loss_fn(real_output, real_labels)
            
            z = torch.randn(batch_size_current, 100).to(device)
            fake_imgs = generator(z)
            fake_output = discriminator(fake_imgs.detach())
            d_loss_fake = loss_fn(fake_output, fake_labels)
            
            d_loss = d_loss_real + d_loss_fake
            d_loss.backward()
            opt_D.step()

            # 更新生成器
            generator.zero_grad()
            fake_output = discriminator(fake_imgs)
            g_loss = loss_fn(fake_output, torch.ones(batch_size_current, 1).to(device))
            g_loss.backward()
            opt_G.step()
            
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            num_batches += 1

        avg_d_loss = epoch_d_loss / num_batches
        avg_g_loss = epoch_g_loss / num_batches
        G_losses.append(avg_g_loss)
        D_losses.append(avg_d_loss)
        
        # 新增：记录当前epoch的sigma值
        if use_vsig and hasattr(discriminator.activation, 'sigma'):
            current_sigma = discriminator.activation.sigma.item()
            sigma_values.append(current_sigma)
            print(f"[{model_name}] Epoch {epoch+1}/{epochs} | D_loss: {avg_d_loss:.4f} | G_loss: {avg_g_loss:.4f} | Sigma: {current_sigma:.4f}")
        else:
            print(f"[{model_name}] Epoch {epoch+1}/{epochs} | D_loss: {avg_d_loss:.4f} | G_loss: {avg_g_loss:.4f}")
        
        if (epoch + 1) % 10 == 0:
            save_sample_images(generator, epoch + 1, model_name)

    # 保存模型
    os.makedirs(BASE_PATH, exist_ok=True)
    torch.save(generator.state_dict(), f'{BASE_PATH}/generator_{model_name}.pth')
    torch.save(discriminator.state_dict(), f'{BASE_PATH}/discriminator_{model_name}.pth')
    
    plot_losses(G_losses, D_losses, model_name)
    
    # 新增：如果使用Vsig，绘制sigma值变化图
    if use_vsig and sigma_values:
        plot_sigma_evolution(sigma_values, model_name)
        # 保存sigma值数据
        np.save(f'{BASE_PATH}/sigma_values_{model_name}.npy', np.array(sigma_values))
        print(f"Sigma值变化已保存到: {BASE_PATH}/sigma_values_{model_name}.npy")
    
    return generator

# -------------------------------
# 4. 新增：绘制sigma值变化图
# -------------------------------
def plot_sigma_evolution(sigma_values, model_name):
    """绘制sigma值随epoch的变化"""
    plt.figure(figsize=(10, 6))
    epochs = range(1, len(sigma_values) + 1)
    plt.plot(epochs, sigma_values, 'b-', linewidth=2, marker='o', markersize=4)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Sigma Value', fontsize=12)
    plt.title(f'Vsig Sigma Parameter Evolution - {model_name}', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.xlim(1, len(sigma_values))
    
    # 添加统计信息
    initial_sigma = sigma_values[0]
    final_sigma = sigma_values[-1]
    min_sigma = min(sigma_values)
    max_sigma = max(sigma_values)
    
    plt.text(0.02, 0.98, f'Initial: {initial_sigma:.4f}\nFinal: {final_sigma:.4f}\nMin: {min_sigma:.4f}\nMax: {max_sigma:.4f}', 
             transform=plt.gca().transAxes, verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
    
    plt.tight_layout()
    plt.savefig(f'{BASE_PATH}/sigma_evolution_{model_name}.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"Sigma值变化图已保存到: {BASE_PATH}/sigma_evolution_{model_name}.png")

# -------------------------------
# 5. 保存样本图像
# -------------------------------
def save_sample_images(generator, epoch, model_name, num_samples=64):
    device = next(generator.parameters()).device
    generator.eval()
    
    os.makedirs(f"{BASE_PATH}/samples_{model_name}/", exist_ok=True)
    
    with torch.no_grad():
        z = torch.randn(num_samples, 100).to(device)
        fake_imgs = generator(z)
        utils.save_image(fake_imgs, f'{BASE_PATH}/samples_{model_name}/epoch_{epoch:03d}.png', 
                        normalize=True, nrow=8)
    
    generator.train()

# -------------------------------
# 6. 保存生成图像用于评估
# -------------------------------
def save_generated_images(generator, model_name="sigmoid", num_images=1000):
    device = next(generator.parameters()).device
    generator.eval()

    save_dir = f"{BASE_PATH}/images_fake_{model_name}/"
    os.makedirs(save_dir, exist_ok=True)

    print(f"正在保存 {num_images} 张生成图像...")
    with torch.no_grad():
        for i in tqdm(range(num_images)):
            z = torch.randn(1, 100).to(device)
            fake_img = generator(z).cpu()
            fake_img = (fake_img + 1) / 2
            fake_img = torch.clamp(fake_img, 0, 1)
            img_path = os.path.join(save_dir, f"{i:04d}.png")
            utils.save_image(fake_img, img_path)

# -------------------------------
# 7. 保存真实CIFAR-10图像
# -------------------------------
def save_real_cifar10_images(num_images=1000):
    transform = transforms.Compose([transforms.ToTensor()])
    dataset = datasets.CIFAR10("./data", train=True, download=True, transform=transform)
    
    save_dir = f"{BASE_PATH}/images_real_cifar10/"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"正在保存 {num_images} 张真实CIFAR-10图像...")
    for i in tqdm(range(num_images)):
        img, _ = dataset[i]
        img_path = os.path.join(save_dir, f"{i:04d}.png")
        utils.save_image(img, img_path)

# -------------------------------
# 8. 使用专业包计算FID和IS
# -------------------------------
def calculate_fid_pytorch_fid(real_path, fake_path, device='cuda'):
    """使用pytorch-fid包计算FID"""
    if not PYTORCH_FID_AVAILABLE:
        print("pytorch-fid 不可用，跳过计算")
        return None
    
    try:
        print("使用pytorch-fid计算FID...")
        fid_value = fid_score.calculate_fid_given_paths([real_path, fake_path], 
                                                       batch_size=50, 
                                                       device=device, 
                                                       dims=2048)
        return fid_value
    except Exception as e:
        print(f"pytorch-fid计算失败: {e}")
        return None

def calculate_metrics_torchmetrics(real_path, fake_path, device='cuda'):
    """使用torchmetrics计算FID和IS"""
    if not TORCHMETRICS_AVAILABLE:
        print("torchmetrics 不可用，跳过计算")
        return None, None, None

    try:
        # 数据预处理
        transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        real_dataset = ImageFolderDataset(real_path, transform=transform)
        fake_dataset = ImageFolderDataset(fake_path, transform=transform)
        
        real_loader = DataLoader(real_dataset, batch_size=32, shuffle=False)
        fake_loader = DataLoader(fake_dataset, batch_size=32, shuffle=False)
        
        # 初始化指标
        fid = FrechetInceptionDistance(feature=2048, normalize=True).to(device)
        inception_score = InceptionScore(normalize=True).to(device)
        
        print("使用torchmetrics计算指标...")
        
        # 更新FID
        for real_batch in tqdm(real_loader, desc="处理真实图像"):
            real_batch = real_batch.to(device)
            # 确保图像是RGB格式并且在正确范围内
            if real_batch.shape[1] == 1:
                real_batch = real_batch.repeat(1, 3, 1, 1)
            real_batch = (real_batch + 1) / 2  # 转换到[0,1]
            real_batch = torch.clamp(real_batch, 0, 1)
            fid.update(real_batch, real=True)
        
        for fake_batch in tqdm(fake_loader, desc="处理生成图像"):
            fake_batch = fake_batch.to(device)
            if fake_batch.shape[1] == 1:
                fake_batch = fake_batch.repeat(1, 3, 1, 1)
            fake_batch = (fake_batch + 1) / 2
            fake_batch = torch.clamp(fake_batch, 0, 1)
            fid.update(fake_batch, real=False)
            
            # 更新IS
            inception_score.update(fake_batch)
        
        # 计算最终分数
        fid_score = fid.compute().item()
        is_mean, is_std = inception_score.compute()
        is_mean, is_std = is_mean.item(), is_std.item()
        
        return fid_score, is_mean, is_std
        
    except Exception as e:
        print(f"torchmetrics计算失败: {e}")
        return None, None, None

# -------------------------------
# 9. 图像数据集类
# -------------------------------
class ImageFolderDataset(Dataset):
    def __init__(self, root, transform=None):
        self.root = root
        self.transform = transform
        self.images = [f for f in os.listdir(root) if f.endswith(('.png', '.jpg', '.jpeg'))]
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.root, self.images[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# -------------------------------
# 10. 自定义IS和FID实现（备用）
# -------------------------------
def compute_inception_score_custom(images, device='cuda', batch_size=32, splits=10):
    """自定义IS计算（当专业包不可用时使用）"""
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()
    
    up = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)
    
    def get_pred(x):
        if x.shape[1] == 1:
            x = x.repeat(1, 3, 1, 1)
        x = up(x)
        x = inception_model(x)
        return torch.nn.functional.softmax(x, dim=1).data.cpu().numpy()

    dataloader = DataLoader(images, batch_size=batch_size, shuffle=False)
    preds = []
    
    print("计算Inception Score (自定义实现)...")
    with torch.no_grad():
        for batch in tqdm(dataloader):
            batch = batch.to(device)
            pred = get_pred(batch)
            preds.append(pred)
    
    preds = np.concatenate(preds, axis=0)
    
    scores = []
    N = preds.shape[0]
    for i in range(splits):
        part = preds[i * (N // splits): (i + 1) * (N // splits), :]
        py = np.mean(part, axis=0)
        scores.append([np.sum(p * (np.log(p + 1e-10) - np.log(py + 1e-10))) for p in part])
    
    scores = np.concatenate(scores)
    is_mean = np.exp(np.mean(scores))
    is_std = np.exp(np.std(scores))
    
    return is_mean, is_std

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    """计算Fréchet距离"""
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)
    
    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)
    
    diff = mu1 - mu2
    
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))
    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real
    
    tr_covmean = np.trace(covmean)
    
    return (diff.dot(diff) + np.trace(sigma1) + 
            np.trace(sigma2) - 2 * tr_covmean)

def compute_fid_score_custom(real_images, fake_images, device='cuda', batch_size=32):
    """自定义FID计算"""
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()
    
    inception_model.fc = nn.Identity()
    
    up = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)
    
    def get_activations(dataset):
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
        activations = []
        
        with torch.no_grad():
            for batch in tqdm(dataloader):
                batch = batch.to(device)
                if batch.shape[1] == 1:
                    batch = batch.repeat(1, 3, 1, 1)
                batch = up(batch)
                pred = inception_model(batch).cpu().numpy()
                activations.append(pred)
        
        return np.concatenate(activations, axis=0)
    
    print("计算真实图像的特征 (自定义实现)...")
    real_activations = get_activations(real_images)
    print("计算生成图像的特征 (自定义实现)...")
    fake_activations = get_activations(fake_images)
    
    mu_real = np.mean(real_activations, axis=0)
    sigma_real = np.cov(real_activations, rowvar=False)
    
    mu_fake = np.mean(fake_activations, axis=0)
    sigma_fake = np.cov(fake_activations, rowvar=False)
    
    fid_score = calculate_frechet_distance(mu_real, sigma_real, mu_fake, sigma_fake)
    
    return fid_score

# -------------------------------
# 11. 综合评估函数
# -------------------------------
def evaluate_model(fake_dir, real_dir, model_name, device='cuda'):
    """综合评估模型"""
    print(f"\n{'='*50}")
    print(f"评估 {model_name} 模型")
    print(f"{'='*50}")
    
    results = {}
    
    # 1. 尝试使用pytorch-fid计算FID
    fid_pytorch = calculate_fid_pytorch_fid(real_dir, fake_dir, device)
    if fid_pytorch is not None:
        results['FID_pytorch'] = fid_pytorch
        print(f"FID (pytorch-fid): {fid_pytorch:.4f}")
    
    # 2. 尝试使用torchmetrics计算FID和IS
    fid_tm, is_mean_tm, is_std_tm = calculate_metrics_torchmetrics(real_dir, fake_dir, device)
    if fid_tm is not None:
        results['FID_torchmetrics'] = fid_tm
        results['IS_mean_torchmetrics'] = is_mean_tm
        results['IS_std_torchmetrics'] = is_std_tm
        print(f"FID (torchmetrics): {fid_tm:.4f}")
        print(f"IS (torchmetrics): {is_mean_tm:.4f} ± {is_std_tm:.4f}")
    
    # 3. 如果专业包都不可用，使用自定义实现
    if not results:
        print("使用自定义实现计算指标...")
        transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        fake_dataset = ImageFolderDataset(fake_dir, transform=transform)
        real_dataset = ImageFolderDataset(real_dir, transform=transform)
        
        # 计算IS
        is_mean_custom, is_std_custom = compute_inception_score_custom(fake_dataset, device=device)
        results['IS_mean_custom'] = is_mean_custom
        results['IS_std_custom'] = is_std_custom
        
        # 计算FID
        fid_custom = compute_fid_score_custom(real_dataset, fake_dataset, device=device)
        results['FID_custom'] = fid_custom
        
        print(f"IS (自定义): {is_mean_custom:.4f} ± {is_std_custom:.4f}")
        print(f"FID (自定义): {fid_custom:.4f}")
    
    return results

# -------------------------------
# 12. 绘制损失曲线
# -------------------------------
def plot_losses(G_losses, D_losses, model_name):
    plt.figure(figsize=(10, 5))
    plt.plot(G_losses, label='Generator Loss')
    plt.plot(D_losses, label='Discriminator Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training Losses - {model_name}')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{BASE_PATH}/losses_{model_name}.png')
    plt.show()

# -------------------------------
# 13. 执行训练和评估
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"使用设备: {device}")
print(f"基础路径: {BASE_PATH}")

# 创建基础目录
os.makedirs(BASE_PATH, exist_ok=True)

# 保存真实CIFAR-10图像
print("保存真实CIFAR-10图像...")
save_real_cifar10_images(num_images=1000)

# 训练两个模型
print("\n训练使用Sigmoid激活函数的GAN...")
generator_sigmoid = train_cifar10_gan(epochs=50, use_vsig=False, model_name="sigmoid")

print("\n训练使用Vsig激活函数的GAN...")  
generator_vsig = train_cifar10_gan(epochs=50, use_vsig=True, model_name="vsig")

# 生成图像用于评估
print("\n生成图像用于评估...")
save_generated_images(generator_sigmoid, model_name="sigmoid", num_images=1000)
save_generated_images(generator_vsig, model_name="vsig", num_images=1000)

# 评估模型
results_sigmoid = evaluate_model(
    f"{BASE_PATH}/images_fake_sigmoid/", 
    f"{BASE_PATH}/images_real_cifar10/", 
    "Sigmoid", device=device)

results_vsig = evaluate_model(
    f"{BASE_PATH}/images_fake_vsig/", 
    f"{BASE_PATH}/images_real_cifar10/", 
    "Vsig", device=device)

# 输出最终对比结果
print("\n" + "="*60)
print("最终结果对比:")
print("="*60)

for metric in results_sigmoid.keys():
    if metric in results_vsig:
        print(f"{metric}:")
        print(f"  Sigmoid: {results_sigmoid[metric]:.4f}")
        print(f"  Vsig:    {results_vsig[metric]:.4f}")
        print()
# Out:
# 检查已下载的模型文件...
# pytorch-fid文件存在: 91.2 MB
# torch-fidelity文件存在: 91.2 MB
# pytorch-fid 状态: 可用
# torchmetrics 状态: 可用
# 使用设备: cuda
# 基础路径: D:/PRE2023 2025
# 保存真实CIFAR-10图像...
# Files already downloaded and verified
# 正在保存 1000 张真实CIFAR-10图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 794.57it/s]
# 训练使用Sigmoid激活函数的GAN...
# Using device: cuda
# Files already downloaded and verified
# 开始训练 sigmoid 模型...
# [sigmoid] Epoch 1/50 | D_loss: 0.8937 | G_loss: 3.3658
# [sigmoid] Epoch 2/50 | D_loss: 0.9962 | G_loss: 2.2358
# [sigmoid] Epoch 3/50 | D_loss: 0.9724 | G_loss: 2.1518
# [sigmoid] Epoch 4/50 | D_loss: 0.9470 | G_loss: 1.9661
# [sigmoid] Epoch 5/50 | D_loss: 0.9895 | G_loss: 1.8912
# [sigmoid] Epoch 6/50 | D_loss: 1.0423 | G_loss: 1.6681
# [sigmoid] Epoch 7/50 | D_loss: 1.0972 | G_loss: 1.6131
# [sigmoid] Epoch 8/50 | D_loss: 1.0916 | G_loss: 1.5801
# [sigmoid] Epoch 9/50 | D_loss: 1.1048 | G_loss: 1.5467
# [sigmoid] Epoch 10/50 | D_loss: 1.1358 | G_loss: 1.4575
# [sigmoid] Epoch 11/50 | D_loss: 1.1004 | G_loss: 1.4736
# [sigmoid] Epoch 12/50 | D_loss: 1.1161 | G_loss: 1.4449
# [sigmoid] Epoch 13/50 | D_loss: 1.1173 | G_loss: 1.4250
# [sigmoid] Epoch 14/50 | D_loss: 1.1045 | G_loss: 1.4136
# [sigmoid] Epoch 15/50 | D_loss: 1.1081 | G_loss: 1.3790
# [sigmoid] Epoch 16/50 | D_loss: 1.1664 | G_loss: 1.3226
# [sigmoid] Epoch 17/50 | D_loss: 1.1519 | G_loss: 1.3208
# [sigmoid] Epoch 18/50 | D_loss: 1.1578 | G_loss: 1.3153
# [sigmoid] Epoch 19/50 | D_loss: 1.1487 | G_loss: 1.3136
# [sigmoid] Epoch 20/50 | D_loss: 1.1568 | G_loss: 1.3196
# [sigmoid] Epoch 21/50 | D_loss: 1.1569 | G_loss: 1.3064
# [sigmoid] Epoch 22/50 | D_loss: 1.1680 | G_loss: 1.3071
# [sigmoid] Epoch 23/50 | D_loss: 1.1463 | G_loss: 1.3128
# [sigmoid] Epoch 24/50 | D_loss: 1.1440 | G_loss: 1.3076
# [sigmoid] Epoch 25/50 | D_loss: 1.1637 | G_loss: 1.3187
# [sigmoid] Epoch 26/50 | D_loss: 1.1463 | G_loss: 1.3119
# [sigmoid] Epoch 27/50 | D_loss: 1.1511 | G_loss: 1.3014
# [sigmoid] Epoch 28/50 | D_loss: 1.1500 | G_loss: 1.2999
# [sigmoid] Epoch 29/50 | D_loss: 1.1319 | G_loss: 1.3272
# [sigmoid] Epoch 30/50 | D_loss: 1.1449 | G_loss: 1.3244
# [sigmoid] Epoch 31/50 | D_loss: 1.1289 | G_loss: 1.3326
# [sigmoid] Epoch 32/50 | D_loss: 1.1334 | G_loss: 1.3313
# [sigmoid] Epoch 33/50 | D_loss: 1.1279 | G_loss: 1.3468
# [sigmoid] Epoch 34/50 | D_loss: 1.1032 | G_loss: 1.3597
# [sigmoid] Epoch 35/50 | D_loss: 1.1219 | G_loss: 1.3774
# [sigmoid] Epoch 36/50 | D_loss: 1.0886 | G_loss: 1.3773
# [sigmoid] Epoch 37/50 | D_loss: 1.1080 | G_loss: 1.3997
# [sigmoid] Epoch 38/50 | D_loss: 1.0766 | G_loss: 1.4072
# [sigmoid] Epoch 39/50 | D_loss: 1.0970 | G_loss: 1.4098
# [sigmoid] Epoch 40/50 | D_loss: 1.0657 | G_loss: 1.4357
# [sigmoid] Epoch 41/50 | D_loss: 1.0500 | G_loss: 1.4663
# [sigmoid] Epoch 42/50 | D_loss: 1.0770 | G_loss: 1.4555
# [sigmoid] Epoch 43/50 | D_loss: 1.1135 | G_loss: 1.4669
# [sigmoid] Epoch 44/50 | D_loss: 1.0365 | G_loss: 1.4487
# [sigmoid] Epoch 45/50 | D_loss: 1.0618 | G_loss: 1.4752
# [sigmoid] Epoch 46/50 | D_loss: 1.0212 | G_loss: 1.5003
# [sigmoid] Epoch 47/50 | D_loss: 1.0186 | G_loss: 1.5334
# [sigmoid] Epoch 48/50 | D_loss: 1.0632 | G_loss: 1.5229
# [sigmoid] Epoch 49/50 | D_loss: 1.0634 | G_loss: 1.5077
# [sigmoid] Epoch 50/50 | D_loss: 1.0102 | G_loss: 1.5269
# 训练使用Vsig激活函数的GAN...
# Using device: cuda
# Files already downloaded and verified
# 开始训练 vsig 模型...
# [vsig] Epoch 1/50 | D_loss: 0.9044 | G_loss: 3.5290 | Sigma: 1.7746
# [vsig] Epoch 2/50 | D_loss: 0.9766 | G_loss: 2.4945 | Sigma: 1.7419
# [vsig] Epoch 3/50 | D_loss: 0.9045 | G_loss: 2.4092 | Sigma: 1.7090
# [vsig] Epoch 4/50 | D_loss: 0.9929 | G_loss: 1.9412 | Sigma: 1.6847
# [vsig] Epoch 5/50 | D_loss: 2.3429 | G_loss: 1.1127 | Sigma: 1.7022
# [vsig] Epoch 6/50 | D_loss: 1.8886 | G_loss: 0.7633 | Sigma: 1.7023
# [vsig] Epoch 7/50 | D_loss: 1.7889 | G_loss: 0.7401 | Sigma: 1.7024
# [vsig] Epoch 8/50 | D_loss: 1.6853 | G_loss: 0.7611 | Sigma: 1.7025
# [vsig] Epoch 9/50 | D_loss: 1.6121 | G_loss: 0.7801 | Sigma: 1.7025
# [vsig] Epoch 10/50 | D_loss: 1.5879 | G_loss: 0.7631 | Sigma: 1.7026
# [vsig] Epoch 11/50 | D_loss: 1.5716 | G_loss: 0.7351 | Sigma: 1.7027
# [vsig] Epoch 12/50 | D_loss: 1.5212 | G_loss: 0.7285 | Sigma: 1.7028
# [vsig] Epoch 13/50 | D_loss: 1.4016 | G_loss: 0.7898 | Sigma: 1.7028
# [vsig] Epoch 14/50 | D_loss: 1.3260 | G_loss: 0.8157 | Sigma: 1.7028
# [vsig] Epoch 15/50 | D_loss: 1.3467 | G_loss: 0.7963 | Sigma: 1.7029
# [vsig] Epoch 16/50 | D_loss: 1.3799 | G_loss: 0.7781 | Sigma: 1.7029
# [vsig] Epoch 17/50 | D_loss: 1.3438 | G_loss: 0.7735 | Sigma: 1.7029
# [vsig] Epoch 18/50 | D_loss: 1.3277 | G_loss: 0.7546 | Sigma: 1.7029
# [vsig] Epoch 19/50 | D_loss: 1.3347 | G_loss: 0.7554 | Sigma: 1.7029
# [vsig] Epoch 20/50 | D_loss: 1.3942 | G_loss: 0.7151 | Sigma: 1.7029
# [vsig] Epoch 21/50 | D_loss: 1.4285 | G_loss: 0.6855 | Sigma: 1.7030
# [vsig] Epoch 22/50 | D_loss: 1.4548 | G_loss: 0.6641 | Sigma: 1.7032
# [vsig] Epoch 23/50 | D_loss: 1.4414 | G_loss: 0.6699 | Sigma: 1.7033
# [vsig] Epoch 24/50 | D_loss: 1.4266 | G_loss: 0.6774 | Sigma: 1.7035
# [vsig] Epoch 25/50 | D_loss: 1.4109 | G_loss: 0.6950 | Sigma: 1.7036
# [vsig] Epoch 26/50 | D_loss: 1.4013 | G_loss: 0.6984 | Sigma: 1.7037
# [vsig] Epoch 27/50 | D_loss: 1.3998 | G_loss: 0.7031 | Sigma: 1.7038
# [vsig] Epoch 28/50 | D_loss: 1.3931 | G_loss: 0.7055 | Sigma: 1.7038
# [vsig] Epoch 29/50 | D_loss: 1.3907 | G_loss: 0.7094 | Sigma: 1.7039
# [vsig] Epoch 30/50 | D_loss: 1.3883 | G_loss: 0.7126 | Sigma: 1.7040
# [vsig] Epoch 31/50 | D_loss: 1.3897 | G_loss: 0.7145 | Sigma: 1.7041
# [vsig] Epoch 32/50 | D_loss: 1.3917 | G_loss: 0.7091 | Sigma: 1.7043
# [vsig] Epoch 33/50 | D_loss: 1.3951 | G_loss: 0.7079 | Sigma: 1.7046
# [vsig] Epoch 34/50 | D_loss: 1.3931 | G_loss: 0.7103 | Sigma: 1.7049
# [vsig] Epoch 35/50 | D_loss: 1.3913 | G_loss: 0.7157 | Sigma: 1.7052
# [vsig] Epoch 36/50 | D_loss: 1.3909 | G_loss: 0.7176 | Sigma: 1.7056
# [vsig] Epoch 37/50 | D_loss: 1.3899 | G_loss: 0.7172 | Sigma: 1.7061
# [vsig] Epoch 38/50 | D_loss: 1.3913 | G_loss: 0.7157 | Sigma: 1.7067
# [vsig] Epoch 39/50 | D_loss: 1.3897 | G_loss: 0.7221 | Sigma: 1.7074
# [vsig] Epoch 40/50 | D_loss: 1.3858 | G_loss: 0.7283 | Sigma: 1.7081
# [vsig] Epoch 41/50 | D_loss: 1.3830 | G_loss: 0.7419 | Sigma: 1.7089
# [vsig] Epoch 42/50 | D_loss: 1.3713 | G_loss: 0.7779 | Sigma: 1.7092
# [vsig] Epoch 43/50 | D_loss: 1.2983 | G_loss: 1.0353 | Sigma: 1.7044
# [vsig] Epoch 44/50 | D_loss: 1.2874 | G_loss: 1.1299 | Sigma: 1.7020
# [vsig] Epoch 45/50 | D_loss: 1.2070 | G_loss: 1.2991 | Sigma: 1.6905
# [vsig] Epoch 46/50 | D_loss: 1.2137 | G_loss: 1.3238 | Sigma: 1.6798
# [vsig] Epoch 47/50 | D_loss: 1.1883 | G_loss: 1.3651 | Sigma: 1.6637
# [vsig] Epoch 48/50 | D_loss: 1.1686 | G_loss: 1.3441 | Sigma: 1.6424
# [vsig] Epoch 49/50 | D_loss: 1.1471 | G_loss: 1.3665 | Sigma: 1.6153
# [vsig] Epoch 50/50 | D_loss: 1.1971 | G_loss: 1.3001 | Sigma: 1.6082
# Sigma值变化图已保存到: D:/PRE2023 2025/sigma_evolution_vsig.png
# Sigma值变化已保存到: D:/PRE2023 2025/sigma_values_vsig.npy
#
# 生成图像用于评估...
# 正在保存 1000 张生成图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 448.18it/s]
# 正在保存 1000 张生成图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 458.13it/s]
# ==================================================
# 评估 Sigmoid 模型
# ==================================================
# 使用pytorch-fid计算FID...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:10<00:00,  1.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:10<00:00,  1.88it/s]
# FID (pytorch-fid): 81.5767
# d:\anaconda\envs\torch2\lib\site-packages\torchmetrics\utilities\prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# 使用torchmetrics计算指标...
# 处理真实图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:02<00:00, 10.89it/s]
# 处理生成图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:04<00:00,  6.74it/s]
# FID (torchmetrics): 80.7613
# IS (torchmetrics): 5.7429 ± 0.5398
#
# ==================================================
# 评估 Vsig 模型
# ==================================================
# 使用pytorch-fid计算FID...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:06<00:00,  3.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:10<00:00,  1.84it/s]
# FID (pytorch-fid): 123.6992
# 使用torchmetrics计算指标...
# 处理真实图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:02<00:00, 12.01it/s]
# 处理生成图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:04<00:00,  6.76it/s]
# FID (torchmetrics): 121.5301
# IS (torchmetrics): 4.3021 ± 0.3220
#
# ============================================================
# 最终结果对比:
# ============================================================
# FID_pytorch:
#   Sigmoid: 81.5767
#   Vsig:    123.6992
#
# FID_torchmetrics:
#   Sigmoid: 80.7613
#   Vsig:    121.5301
#
# IS_mean_torchmetrics:
#   Sigmoid: 5.7429
#   Vsig:    4.3021
#
# IS_std_torchmetrics:
#   Sigmoid: 0.5398
#   Vsig:    0.3220

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, utils
import os
import numpy as np
from torch.utils.data import DataLoader, Dataset
from torch.nn.functional import sigmoid, interpolate
from torchvision.models import inception_v3
from scipy import linalg
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import math

# 检查已下载的文件
cache_dir = os.path.expanduser("~/.cache/torch/hub/checkpoints/")
pytorch_fid_file = os.path.join(cache_dir, "pt_inception-2015-12-05-6726825d.pth")
torch_fidelity_file = os.path.join(cache_dir, "weights-inception-2015-12-05-6726825d.pth")

print("检查已下载的模型文件...")
pytorch_fid_exists = os.path.exists(pytorch_fid_file)
torch_fidelity_exists = os.path.exists(torch_fidelity_file)

if pytorch_fid_exists:
    size_mb = os.path.getsize(pytorch_fid_file) / 1024 / 1024
    print(f"pytorch-fid文件存在: {size_mb:.1f} MB")
else:
    print("pytorch-fid文件不存在")

if torch_fidelity_exists:
    size_mb = os.path.getsize(torch_fidelity_file) / 1024 / 1024
    print(f"torch-fidelity文件存在: {size_mb:.1f} MB")
else:
    print("torch-fidelity文件不存在")

# 使用专业的FID和IS计算包 - 直接尝试使用，不预先检查文件完整性
try:
    from pytorch_fid import fid_score
    from pytorch_fid.inception import InceptionV3
    PYTORCH_FID_AVAILABLE = pytorch_fid_exists  # 只要文件存在就尝试使用
    print(f"pytorch-fid 状态: {'可用' if PYTORCH_FID_AVAILABLE else '不可用'}")
except ImportError:
    PYTORCH_FID_AVAILABLE = False
    print("pytorch-fid 包未安装")

try:
    from torchmetrics.image.fid import FrechetInceptionDistance
    from torchmetrics.image.inception import InceptionScore
    TORCHMETRICS_AVAILABLE = torch_fidelity_exists  # 只要文件存在就尝试使用
    print(f"torchmetrics 状态: {'可用' if TORCHMETRICS_AVAILABLE else '不可用'}")
except ImportError:
    TORCHMETRICS_AVAILABLE = False
    print("torchmetrics 包未安装")

# 修改基础路径
BASE_PATH = "D:/PRE2023 2025"

class Vsig(nn.Module):
    def __init__(self, sigma=1.0):
        super(Vsig, self).__init__()
        # 固定sigma值，不作为可学习参数
        self.sigma = sigma

    def forward(self, input):
        output = torch.atan(input / self.sigma) / math.pi + 0.5
        return output

# -------------------------------
# 2. CIFAR-10 Generator & Discriminator
# -------------------------------
class CIFAR10Generator(nn.Module):
    def __init__(self, latent_dim=100, ngf=64):
        super().__init__()
        self.latent_dim = latent_dim
        
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 2, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        return self.main(z.view(z.size(0), z.size(1), 1, 1))


class CIFAR10Discriminator(nn.Module):
    def __init__(self, sigma=1.0, ndf=64):
        super().__init__()
        
        self.main = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 4, 1, 4, 1, 0, bias=False),
        )
        
        self.activation = Vsig(sigma=sigma)

    def forward(self, x):
        logits = self.main(x)
        return self.activation(logits.view(-1, 1))

# -------------------------------
# 3. 训练函数 (修改版本)
# -------------------------------
def train_cifar10_gan(epochs=50, sigma=1.0, batch_size=128):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    generator = CIFAR10Generator().to(device)
    discriminator = CIFAR10Discriminator(sigma=sigma).to(device)
    
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
            nn.init.normal_(m.weight.data, 1.0, 0.02)
            nn.init.constant_(m.bias.data, 0)
    
    generator.apply(weights_init)
    discriminator.apply(weights_init)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    dataset = datasets.CIFAR10("./data", download=True, train=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)

    lr = 0.0002
    beta1 = 0.5
    opt_G = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, 0.999))
    opt_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

    loss_fn = nn.BCELoss()
    
    G_losses = []
    D_losses = []

    print(f"开始训练 Vsig (sigma={sigma}) 模型...")
    
    for epoch in range(epochs):
        epoch_d_loss = 0
        epoch_g_loss = 0
        num_batches = 0
        
        for i, (real_imgs, _) in enumerate(dataloader):
            real_imgs = real_imgs.to(device)
            batch_size_current = real_imgs.size(0)

            real_labels = torch.ones(batch_size_current, 1).to(device) * 0.9
            fake_labels = torch.zeros(batch_size_current, 1).to(device) + 0.1

            # 更新判别器
            discriminator.zero_grad()
            
            real_output = discriminator(real_imgs)
            d_loss_real = loss_fn(real_output, real_labels)
            
            z = torch.randn(batch_size_current, 100).to(device)
            fake_imgs = generator(z)
            fake_output = discriminator(fake_imgs.detach())
            d_loss_fake = loss_fn(fake_output, fake_labels)
            
            d_loss = d_loss_real + d_loss_fake
            d_loss.backward()
            opt_D.step()

            # 更新生成器
            generator.zero_grad()
            fake_output = discriminator(fake_imgs)
            g_loss = loss_fn(fake_output, torch.ones(batch_size_current, 1).to(device))
            g_loss.backward()
            opt_G.step()
            
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            num_batches += 1

        avg_d_loss = epoch_d_loss / num_batches
        avg_g_loss = epoch_g_loss / num_batches
        G_losses.append(avg_g_loss)
        D_losses.append(avg_d_loss)
        
        print(f"[Vsig σ={sigma}] Epoch {epoch+1}/{epochs} | D_loss: {avg_d_loss:.4f} | G_loss: {avg_g_loss:.4f}")
        
        if (epoch + 1) % 10 == 0:
            save_sample_images(generator, epoch + 1, f"vsig_sigma_{sigma}")

    # 保存模型
    os.makedirs(BASE_PATH, exist_ok=True)
    torch.save(generator.state_dict(), f'{BASE_PATH}/generator_vsig_sigma_{sigma}.pth')
    torch.save(discriminator.state_dict(), f'{BASE_PATH}/discriminator_vsig_sigma_{sigma}.pth')
    
    plot_losses(G_losses, D_losses, f"Vsig (σ={sigma})")
    
    return generator

# -------------------------------
# 4. 保存样本图像
# -------------------------------
def save_sample_images(generator, epoch, model_name, num_samples=64):
    device = next(generator.parameters()).device
    generator.eval()
    
    os.makedirs(f"{BASE_PATH}/samples_{model_name}/", exist_ok=True)
    
    with torch.no_grad():
        z = torch.randn(num_samples, 100).to(device)
        fake_imgs = generator(z)
        utils.save_image(fake_imgs, f'{BASE_PATH}/samples_{model_name}/epoch_{epoch:03d}.png', 
                        normalize=True, nrow=8)
    
    generator.train()

# -------------------------------
# 5. 保存生成图像用于评估
# -------------------------------
def save_generated_images(generator, model_name="vsig", num_images=1000):
    device = next(generator.parameters()).device
    generator.eval()

    save_dir = f"{BASE_PATH}/images_fake_{model_name}/"
    os.makedirs(save_dir, exist_ok=True)

    print(f"正在保存 {num_images} 张生成图像...")
    with torch.no_grad():
        for i in tqdm(range(num_images)):
            z = torch.randn(1, 100).to(device)
            fake_img = generator(z).cpu()
            fake_img = (fake_img + 1) / 2
            fake_img = torch.clamp(fake_img, 0, 1)
            img_path = os.path.join(save_dir, f"{i:04d}.png")
            utils.save_image(fake_img, img_path)

# -------------------------------
# 6. 保存真实CIFAR-10图像
# -------------------------------
def save_real_cifar10_images(num_images=1000):
    transform = transforms.Compose([transforms.ToTensor()])
    dataset = datasets.CIFAR10("./data", train=True, download=True, transform=transform)
    
    save_dir = f"{BASE_PATH}/images_real_cifar10/"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"正在保存 {num_images} 张真实CIFAR-10图像...")
    for i in tqdm(range(num_images)):
        img, _ = dataset[i]
        img_path = os.path.join(save_dir, f"{i:04d}.png")
        utils.save_image(img, img_path)

# -------------------------------
# 7. 使用专业包计算FID和IS
# -------------------------------
def calculate_fid_pytorch_fid(real_path, fake_path, device='cuda'):
    """使用pytorch-fid包计算FID"""
    if not PYTORCH_FID_AVAILABLE:
        print("pytorch-fid 不可用，跳过计算")
        return None
    
    try:
        print("使用pytorch-fid计算FID...")
        fid_value = fid_score.calculate_fid_given_paths([real_path, fake_path], 
                                                       batch_size=50, 
                                                       device=device, 
                                                       dims=2048)
        return fid_value
    except Exception as e:
        print(f"pytorch-fid计算失败: {e}")
        return None

def calculate_metrics_torchmetrics(real_path, fake_path, device='cuda'):
    """使用torchmetrics计算FID和IS"""
    if not TORCHMETRICS_AVAILABLE:
        print("torchmetrics 不可用，跳过计算")
        return None, None, None

    try:
        # 数据预处理
        transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        real_dataset = ImageFolderDataset(real_path, transform=transform)
        fake_dataset = ImageFolderDataset(fake_path, transform=transform)
        
        real_loader = DataLoader(real_dataset, batch_size=32, shuffle=False)
        fake_loader = DataLoader(fake_dataset, batch_size=32, shuffle=False)
        
        # 初始化指标
        fid = FrechetInceptionDistance(feature=2048, normalize=True).to(device)
        inception_score = InceptionScore(normalize=True).to(device)
        
        print("使用torchmetrics计算指标...")
        
        # 更新FID
        for real_batch in tqdm(real_loader, desc="处理真实图像"):
            real_batch = real_batch.to(device)
            # 确保图像是RGB格式并且在正确范围内
            if real_batch.shape[1] == 1:
                real_batch = real_batch.repeat(1, 3, 1, 1)
            real_batch = (real_batch + 1) / 2  # 转换到[0,1]
            real_batch = torch.clamp(real_batch, 0, 1)
            fid.update(real_batch, real=True)
        
        for fake_batch in tqdm(fake_loader, desc="处理生成图像"):
            fake_batch = fake_batch.to(device)
            if fake_batch.shape[1] == 1:
                fake_batch = fake_batch.repeat(1, 3, 1, 1)
            fake_batch = (fake_batch + 1) / 2
            fake_batch = torch.clamp(fake_batch, 0, 1)
            fid.update(fake_batch, real=False)
            
            # 更新IS
            inception_score.update(fake_batch)
        
        # 计算最终分数
        fid_score = fid.compute().item()
        is_mean, is_std = inception_score.compute()
        is_mean, is_std = is_mean.item(), is_std.item()
        
        return fid_score, is_mean, is_std
        
    except Exception as e:
        print(f"torchmetrics计算失败: {e}")
        return None, None, None

# -------------------------------
# 8. 图像数据集类
# -------------------------------
class ImageFolderDataset(Dataset):
    def __init__(self, root, transform=None):
        self.root = root
        self.transform = transform
        self.images = [f for f in os.listdir(root) if f.endswith(('.png', '.jpg', '.jpeg'))]
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.root, self.images[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# -------------------------------
# 9. 自定义IS和FID实现（备用）
# -------------------------------
def compute_inception_score_custom(images, device='cuda', batch_size=32, splits=10):
    """自定义IS计算（当专业包不可用时使用）"""
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()
    
    up = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)
    
    def get_pred(x):
        if x.shape[1] == 1:
            x = x.repeat(1, 3, 1, 1)
        x = up(x)
        x = inception_model(x)
        return torch.nn.functional.softmax(x, dim=1).data.cpu().numpy()

    dataloader = DataLoader(images, batch_size=batch_size, shuffle=False)
    preds = []
    
    print("计算Inception Score (自定义实现)...")
    with torch.no_grad():
        for batch in tqdm(dataloader):
            batch = batch.to(device)
            pred = get_pred(batch)
            preds.append(pred)
    
    preds = np.concatenate(preds, axis=0)
    
    scores = []
    N = preds.shape[0]
    for i in range(splits):
        part = preds[i * (N // splits): (i + 1) * (N // splits), :]
        py = np.mean(part, axis=0)
        scores.append([np.sum(p * (np.log(p + 1e-10) - np.log(py + 1e-10))) for p in part])
    
    scores = np.concatenate(scores)
    is_mean = np.exp(np.mean(scores))
    is_std = np.exp(np.std(scores))
    
    return is_mean, is_std

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    """计算Fréchet距离"""
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)
    
    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)
    
    diff = mu1 - mu2
    
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))
    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real
    
    tr_covmean = np.trace(covmean)
    
    return (diff.dot(diff) + np.trace(sigma1) + 
            np.trace(sigma2) - 2 * tr_covmean)

def compute_fid_score_custom(real_images, fake_images, device='cuda', batch_size=32):
    """自定义FID计算"""
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()
    
    inception_model.fc = nn.Identity()
    
    up = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)
    
    def get_activations(dataset):
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
        activations = []
        
        with torch.no_grad():
            for batch in tqdm(dataloader):
                batch = batch.to(device)
                if batch.shape[1] == 1:
                    batch = batch.repeat(1, 3, 1, 1)
                batch = up(batch)
                pred = inception_model(batch).cpu().numpy()
                activations.append(pred)
        
        return np.concatenate(activations, axis=0)
    
    print("计算真实图像的特征 (自定义实现)...")
    real_activations = get_activations(real_images)
    print("计算生成图像的特征 (自定义实现)...")
    fake_activations = get_activations(fake_images)
    
    mu_real = np.mean(real_activations, axis=0)
    sigma_real = np.cov(real_activations, rowvar=False)
    
    mu_fake = np.mean(fake_activations, axis=0)
    sigma_fake = np.cov(fake_activations, rowvar=False)
    
    fid_score = calculate_frechet_distance(mu_real, sigma_real, mu_fake, sigma_fake)
    
    return fid_score

# -------------------------------
# 10. 综合评估函数
# -------------------------------
def evaluate_model(fake_dir, real_dir, model_name, device='cuda'):
    """综合评估模型"""
    print(f"\n{'='*50}")
    print(f"评估 {model_name} 模型")
    print(f"{'='*50}")
    
    results = {}
    
    # 1. 尝试使用pytorch-fid计算FID
    fid_pytorch = calculate_fid_pytorch_fid(real_dir, fake_dir, device)
    if fid_pytorch is not None:
        results['FID_pytorch'] = fid_pytorch
        print(f"FID (pytorch-fid): {fid_pytorch:.4f}")
    
    # 2. 尝试使用torchmetrics计算FID和IS
    fid_tm, is_mean_tm, is_std_tm = calculate_metrics_torchmetrics(real_dir, fake_dir, device)
    if fid_tm is not None:
        results['FID_torchmetrics'] = fid_tm
        results['IS_mean_torchmetrics'] = is_mean_tm
        results['IS_std_torchmetrics'] = is_std_tm
        print(f"FID (torchmetrics): {fid_tm:.4f}")
        print(f"IS (torchmetrics): {is_mean_tm:.4f} ± {is_std_tm:.4f}")
    
    # 3. 如果专业包都不可用，使用自定义实现
    if not results:
        print("使用自定义实现计算指标...")
        transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        fake_dataset = ImageFolderDataset(fake_dir, transform=transform)
        real_dataset = ImageFolderDataset(real_dir, transform=transform)
        
        # 计算IS
        is_mean_custom, is_std_custom = compute_inception_score_custom(fake_dataset, device=device)
        results['IS_mean_custom'] = is_mean_custom
        results['IS_std_custom'] = is_std_custom
        
        # 计算FID
        fid_custom = compute_fid_score_custom(real_dataset, fake_dataset, device=device)
        results['FID_custom'] = fid_custom
        
        print(f"IS (自定义): {is_mean_custom:.4f} ± {is_std_custom:.4f}")
        print(f"FID (自定义): {fid_custom:.4f}")
    
    return results

# -------------------------------
# 11. 绘制损失曲线
# -------------------------------
def plot_losses(G_losses, D_losses, model_name):
    plt.figure(figsize=(10, 5))
    plt.plot(G_losses, label='Generator Loss')
    plt.plot(D_losses, label='Discriminator Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training Losses - {model_name}')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{BASE_PATH}/losses_{model_name.replace("=", "_").replace("(", "").replace(")", "").replace(" ", "_")}.png')
    plt.show()

# -------------------------------
# 12. 执行训练和评估
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"使用设备: {device}")
print(f"基础路径: {BASE_PATH}")

# 创建基础目录
os.makedirs(BASE_PATH, exist_ok=True)

# 保存真实CIFAR-10图像
print("保存真实CIFAR-10图像...")
save_real_cifar10_images(num_images=1000)

# 训练使用固定sigma的Vsig模型
sigma_value = 1.0 # 可以修改这个值来测试不同的sigma
print(f"\n训练使用Vsig激活函数的GAN (固定σ={sigma_value})...")
generator_vsig = train_cifar10_gan(epochs=50, sigma=sigma_value)

# 生成图像用于评估
print(f"\n生成图像用于评估...")
model_name = f"vsig_sigma_{sigma_value}"
save_generated_images(generator_vsig, model_name=model_name, num_images=1000)

# 评估模型
results_vsig = evaluate_model(
    f"{BASE_PATH}/images_fake_{model_name}/", 
    f"{BASE_PATH}/images_real_cifar10/", 
    f"Vsig (σ={sigma_value})", device=device)

# 输出最终结果
print("\n" + "="*60)
print(f"Vsig (σ={sigma_value}) 模型最终结果:")
print("="*60)

for metric, value in results_vsig.items():
    print(f"{metric}: {value:.4f}")

print(f"\n训练完成！模型和结果已保存到 {BASE_PATH}")
# Out:
# 检查已下载的模型文件...
# pytorch-fid文件存在: 91.2 MB
# torch-fidelity文件存在: 91.2 MB
# pytorch-fid 状态: 可用
# torchmetrics 状态: 可用
# 使用设备: cuda
# 基础路径: D:/PRE2023 2025
# 保存真实CIFAR-10图像...
# Files already downloaded and verified
# 正在保存 1000 张真实CIFAR-10图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 883.43it/s]
# 训练使用Vsig激活函数的GAN (固定σ=1.0)...
# Using device: cuda
# Files already downloaded and verified
# 开始训练 Vsig (sigma=1.0) 模型...
# [Vsig σ=1.0] Epoch 1/50 | D_loss: 1.0987 | G_loss: 2.0800
# [Vsig σ=1.0] Epoch 2/50 | D_loss: 1.2826 | G_loss: 1.1057
# [Vsig σ=1.0] Epoch 3/50 | D_loss: 1.1665 | G_loss: 1.3941
# [Vsig σ=1.0] Epoch 4/50 | D_loss: 1.1031 | G_loss: 1.5431
# [Vsig σ=1.0] Epoch 5/50 | D_loss: 1.0474 | G_loss: 1.5701
# [Vsig σ=1.0] Epoch 6/50 | D_loss: 1.0910 | G_loss: 1.4533
# [Vsig σ=1.0] Epoch 7/50 | D_loss: 1.1469 | G_loss: 1.3907
# [Vsig σ=1.0] Epoch 8/50 | D_loss: 1.1518 | G_loss: 1.3996
# [Vsig σ=1.0] Epoch 9/50 | D_loss: 1.1619 | G_loss: 1.3573
# [Vsig σ=1.0] Epoch 10/50 | D_loss: 1.1458 | G_loss: 1.3516
# [Vsig σ=1.0] Epoch 11/50 | D_loss: 1.1212 | G_loss: 1.3277
# [Vsig σ=1.0] Epoch 12/50 | D_loss: 1.1312 | G_loss: 1.3105
# [Vsig σ=1.0] Epoch 13/50 | D_loss: 1.1409 | G_loss: 1.2952
# [Vsig σ=1.0] Epoch 14/50 | D_loss: 1.1405 | G_loss: 1.3066
# [Vsig σ=1.0] Epoch 15/50 | D_loss: 1.1277 | G_loss: 1.3119
# [Vsig σ=1.0] Epoch 16/50 | D_loss: 1.1370 | G_loss: 1.3037
# [Vsig σ=1.0] Epoch 17/50 | D_loss: 1.1364 | G_loss: 1.2898
# [Vsig σ=1.0] Epoch 18/50 | D_loss: 1.1331 | G_loss: 1.2884
# [Vsig σ=1.0] Epoch 19/50 | D_loss: 1.1284 | G_loss: 1.2935
# [Vsig σ=1.0] Epoch 20/50 | D_loss: 1.1256 | G_loss: 1.2948
# [Vsig σ=1.0] Epoch 21/50 | D_loss: 1.1240 | G_loss: 1.2973
# [Vsig σ=1.0] Epoch 22/50 | D_loss: 1.1246 | G_loss: 1.3000
# [Vsig σ=1.0] Epoch 23/50 | D_loss: 1.1194 | G_loss: 1.2976
# [Vsig σ=1.0] Epoch 24/50 | D_loss: 1.1105 | G_loss: 1.3050
# [Vsig σ=1.0] Epoch 25/50 | D_loss: 1.1228 | G_loss: 1.3104
# [Vsig σ=1.0] Epoch 26/50 | D_loss: 1.1226 | G_loss: 1.3078
# [Vsig σ=1.0] Epoch 27/50 | D_loss: 1.1036 | G_loss: 1.3094
# [Vsig σ=1.0] Epoch 28/50 | D_loss: 1.1105 | G_loss: 1.3031
# [Vsig σ=1.0] Epoch 29/50 | D_loss: 1.1094 | G_loss: 1.3136
# [Vsig σ=1.0] Epoch 30/50 | D_loss: 1.1013 | G_loss: 1.3242
# [Vsig σ=1.0] Epoch 31/50 | D_loss: 1.1170 | G_loss: 1.3127
# [Vsig σ=1.0] Epoch 32/50 | D_loss: 1.0994 | G_loss: 1.3195
# [Vsig σ=1.0] Epoch 33/50 | D_loss: 1.0836 | G_loss: 1.3350
# [Vsig σ=1.0] Epoch 34/50 | D_loss: 1.1000 | G_loss: 1.3378
# [Vsig σ=1.0] Epoch 35/50 | D_loss: 1.0827 | G_loss: 1.3447
# [Vsig σ=1.0] Epoch 36/50 | D_loss: 1.0941 | G_loss: 1.3423
# [Vsig σ=1.0] Epoch 37/50 | D_loss: 1.0813 | G_loss: 1.3598
# [Vsig σ=1.0] Epoch 38/50 | D_loss: 1.0775 | G_loss: 1.3565
# [Vsig σ=1.0] Epoch 39/50 | D_loss: 1.0644 | G_loss: 1.3693
# [Vsig σ=1.0] Epoch 40/50 | D_loss: 1.0799 | G_loss: 1.3642
# [Vsig σ=1.0] Epoch 41/50 | D_loss: 1.0526 | G_loss: 1.3858
# [Vsig σ=1.0] Epoch 42/50 | D_loss: 1.0694 | G_loss: 1.3693
# [Vsig σ=1.0] Epoch 43/50 | D_loss: 1.0605 | G_loss: 1.3774
# [Vsig σ=1.0] Epoch 44/50 | D_loss: 1.0599 | G_loss: 1.3906
# [Vsig σ=1.0] Epoch 45/50 | D_loss: 1.0486 | G_loss: 1.3902
# [Vsig σ=1.0] Epoch 46/50 | D_loss: 1.0475 | G_loss: 1.4030
# [Vsig σ=1.0] Epoch 47/50 | D_loss: 1.0417 | G_loss: 1.4076
# [Vsig σ=1.0] Epoch 48/50 | D_loss: 1.0312 | G_loss: 1.4144
# [Vsig σ=1.0] Epoch 49/50 | D_loss: 1.0271 | G_loss: 1.4274
# [Vsig σ=1.0] Epoch 50/50 | D_loss: 1.0331 | G_loss: 1.4254
# 生成图像用于评估...
# 正在保存 1000 张生成图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 428.30it/s]
# ==================================================
# 评估 Vsig (σ=1.0) 模型
# ==================================================
# 使用pytorch-fid计算FID...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:11<00:00,  1.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:11<00:00,  1.71it/s]
# FID (pytorch-fid): 81.5899
# d:\anaconda\envs\torch2\lib\site-packages\torchmetrics\utilities\prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# 使用torchmetrics计算指标...
# 处理真实图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:04<00:00,  7.64it/s]
# 处理生成图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:06<00:00,  5.30it/s]
# FID (torchmetrics): 81.2653
# IS (torchmetrics): 5.4876 ± 0.3458
#
# ============================================================
# Vsig (σ=1.0) 模型最终结果:
# ============================================================
# FID_pytorch: 81.5899
# FID_torchmetrics: 81.2653
# IS_mean_torchmetrics: 5.4876
# IS_std_torchmetrics: 0.3458
#
# 训练完成！模型和结果已保存到 D:/PRE2023 2025

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, utils
import os
import numpy as np
from torch.utils.data import DataLoader, Dataset
from torch.nn.functional import sigmoid, interpolate
from torchvision.models import inception_v3
from scipy import linalg
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import math

# 检查已下载的文件
cache_dir = os.path.expanduser("~/.cache/torch/hub/checkpoints/")
pytorch_fid_file = os.path.join(cache_dir, "pt_inception-2015-12-05-6726825d.pth")
torch_fidelity_file = os.path.join(cache_dir, "weights-inception-2015-12-05-6726825d.pth")

print("检查已下载的模型文件...")
pytorch_fid_exists = os.path.exists(pytorch_fid_file)
torch_fidelity_exists = os.path.exists(torch_fidelity_file)

if pytorch_fid_exists:
    size_mb = os.path.getsize(pytorch_fid_file) / 1024 / 1024
    print(f"pytorch-fid文件存在: {size_mb:.1f} MB")
else:
    print("pytorch-fid文件不存在")

if torch_fidelity_exists:
    size_mb = os.path.getsize(torch_fidelity_file) / 1024 / 1024
    print(f"torch-fidelity文件存在: {size_mb:.1f} MB")
else:
    print("torch-fidelity文件不存在")

# 使用专业的FID和IS计算包 - 直接尝试使用，不预先检查文件完整性
try:
    from pytorch_fid import fid_score
    from pytorch_fid.inception import InceptionV3
    PYTORCH_FID_AVAILABLE = pytorch_fid_exists  # 只要文件存在就尝试使用
    print(f"pytorch-fid 状态: {'可用' if PYTORCH_FID_AVAILABLE else '不可用'}")
except ImportError:
    PYTORCH_FID_AVAILABLE = False
    print("pytorch-fid 包未安装")

try:
    from torchmetrics.image.fid import FrechetInceptionDistance
    from torchmetrics.image.inception import InceptionScore
    TORCHMETRICS_AVAILABLE = torch_fidelity_exists  # 只要文件存在就尝试使用
    print(f"torchmetrics 状态: {'可用' if TORCHMETRICS_AVAILABLE else '不可用'}")
except ImportError:
    TORCHMETRICS_AVAILABLE = False
    print("torchmetrics 包未安装")

# 修改基础路径
BASE_PATH = "D:/PRE2023 2025"

# -------------------------------
# 1. Activation Function: Vsig
# -------------------------------
class Vsig(nn.Module):
    def __init__(self, init_sigma=1.2):
        super(Vsig, self).__init__()
        self.sigma = nn.Parameter(torch.tensor(init_sigma, dtype=torch.float32))

    def forward(self, input):
        eps = 1e-6
        sigma_safe = self.sigma + eps
        output = torch.atan(input / sigma_safe) / math.pi + 0.5
        return output

# -------------------------------
# 2. CIFAR-10 Generator & Discriminator
# -------------------------------
class CIFAR10Generator(nn.Module):
    def __init__(self, latent_dim=100, ngf=64):
        super().__init__()
        self.latent_dim = latent_dim
        
        self.main = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 2, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        return self.main(z.view(z.size(0), z.size(1), 1, 1))

class CIFAR10Discriminator(nn.Module):
    def __init__(self, use_vsig=False, ndf=64):
        super().__init__()
        self.use_vsig = use_vsig
        
        self.main = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 4, 1, 4, 1, 0, bias=False),
        )
        
        self.activation = Vsig() if use_vsig else nn.Sigmoid()

    def forward(self, x):
        logits = self.main(x)
        return self.activation(logits.view(-1, 1))

# -------------------------------
# 3. Training Function (修改版本 - 记录sigma值)
# -------------------------------
def train_cifar10_gan(epochs=50, use_vsig=False, model_name="sigmoid", batch_size=128):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    generator = CIFAR10Generator().to(device)
    discriminator = CIFAR10Discriminator(use_vsig).to(device)
    
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
            nn.init.normal_(m.weight.data, 1.0, 0.02)
            nn.init.constant_(m.bias.data, 0)
    
    generator.apply(weights_init)
    discriminator.apply(weights_init)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    dataset = datasets.CIFAR10("./data", download=True, train=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)

    lr = 0.0002
    beta1 = 0.5
    opt_G = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, 0.999))
    opt_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

    loss_fn = nn.BCELoss()
    
    G_losses = []
    D_losses = []
    sigma_values = []  # 新增：记录sigma值

    print(f"开始训练 {model_name} 模型...")
    
    for epoch in range(epochs):
        epoch_d_loss = 0
        epoch_g_loss = 0
        num_batches = 0
        
        for i, (real_imgs, _) in enumerate(dataloader):
            real_imgs = real_imgs.to(device)
            batch_size_current = real_imgs.size(0)

            real_labels = torch.ones(batch_size_current, 1).to(device) * 0.9
            fake_labels = torch.zeros(batch_size_current, 1).to(device) + 0.1

            # 更新判别器
            discriminator.zero_grad()
            
            real_output = discriminator(real_imgs)
            d_loss_real = loss_fn(real_output, real_labels)
            
            z = torch.randn(batch_size_current, 100).to(device)
            fake_imgs = generator(z)
            fake_output = discriminator(fake_imgs.detach())
            d_loss_fake = loss_fn(fake_output, fake_labels)
            
            d_loss = d_loss_real + d_loss_fake
            d_loss.backward()
            opt_D.step()

            # 更新生成器
            generator.zero_grad()
            fake_output = discriminator(fake_imgs)
            g_loss = loss_fn(fake_output, torch.ones(batch_size_current, 1).to(device))
            g_loss.backward()
            opt_G.step()
            
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            num_batches += 1

        avg_d_loss = epoch_d_loss / num_batches
        avg_g_loss = epoch_g_loss / num_batches
        G_losses.append(avg_g_loss)
        D_losses.append(avg_d_loss)
        
        # 新增：记录当前epoch的sigma值
        if use_vsig and hasattr(discriminator.activation, 'sigma'):
            current_sigma = discriminator.activation.sigma.item()
            sigma_values.append(current_sigma)
            print(f"[{model_name}] Epoch {epoch+1}/{epochs} | D_loss: {avg_d_loss:.4f} | G_loss: {avg_g_loss:.4f} | Sigma: {current_sigma:.4f}")
        else:
            print(f"[{model_name}] Epoch {epoch+1}/{epochs} | D_loss: {avg_d_loss:.4f} | G_loss: {avg_g_loss:.4f}")
        
        if (epoch + 1) % 10 == 0:
            save_sample_images(generator, epoch + 1, model_name)

    # 保存模型
    os.makedirs(BASE_PATH, exist_ok=True)
    torch.save(generator.state_dict(), f'{BASE_PATH}/generator_{model_name}.pth')
    torch.save(discriminator.state_dict(), f'{BASE_PATH}/discriminator_{model_name}.pth')
    
    plot_losses(G_losses, D_losses, model_name)
    
    # 新增：如果使用Vsig，绘制sigma值变化图
    if use_vsig and sigma_values:
        plot_sigma_evolution(sigma_values, model_name)
        # 保存sigma值数据
        np.save(f'{BASE_PATH}/sigma_values_{model_name}.npy', np.array(sigma_values))
        print(f"Sigma值变化已保存到: {BASE_PATH}/sigma_values_{model_name}.npy")
    
    return generator

# -------------------------------
# 4. 新增：绘制sigma值变化图
# -------------------------------
def plot_sigma_evolution(sigma_values, model_name):
    """绘制sigma值随epoch的变化"""
    plt.figure(figsize=(10, 6))
    epochs = range(1, len(sigma_values) + 1)
    plt.plot(epochs, sigma_values, 'b-', linewidth=2, marker='o', markersize=4)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Sigma Value', fontsize=12)
    plt.title(f'Vsig Sigma Parameter Evolution - {model_name}', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.xlim(1, len(sigma_values))
    
    # 添加统计信息
    initial_sigma = sigma_values[0]
    final_sigma = sigma_values[-1]
    min_sigma = min(sigma_values)
    max_sigma = max(sigma_values)
    
    plt.text(0.02, 0.98, f'Initial: {initial_sigma:.4f}\nFinal: {final_sigma:.4f}\nMin: {min_sigma:.4f}\nMax: {max_sigma:.4f}', 
             transform=plt.gca().transAxes, verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
    
    plt.tight_layout()
    plt.savefig(f'{BASE_PATH}/sigma_evolution_{model_name}.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"Sigma值变化图已保存到: {BASE_PATH}/sigma_evolution_{model_name}.png")

# -------------------------------
# 5. 保存样本图像
# -------------------------------
def save_sample_images(generator, epoch, model_name, num_samples=64):
    device = next(generator.parameters()).device
    generator.eval()
    
    os.makedirs(f"{BASE_PATH}/samples_{model_name}/", exist_ok=True)
    
    with torch.no_grad():
        z = torch.randn(num_samples, 100).to(device)
        fake_imgs = generator(z)
        utils.save_image(fake_imgs, f'{BASE_PATH}/samples_{model_name}/epoch_{epoch:03d}.png', 
                        normalize=True, nrow=8)
    
    generator.train()

# -------------------------------
# 6. 保存生成图像用于评估
# -------------------------------
def save_generated_images(generator, model_name="sigmoid", num_images=1000):
    device = next(generator.parameters()).device
    generator.eval()

    save_dir = f"{BASE_PATH}/images_fake_{model_name}/"
    os.makedirs(save_dir, exist_ok=True)

    print(f"正在保存 {num_images} 张生成图像...")
    with torch.no_grad():
        for i in tqdm(range(num_images)):
            z = torch.randn(1, 100).to(device)
            fake_img = generator(z).cpu()
            fake_img = (fake_img + 1) / 2
            fake_img = torch.clamp(fake_img, 0, 1)
            img_path = os.path.join(save_dir, f"{i:04d}.png")
            utils.save_image(fake_img, img_path)

# -------------------------------
# 7. 保存真实CIFAR-10图像
# -------------------------------
def save_real_cifar10_images(num_images=1000):
    transform = transforms.Compose([transforms.ToTensor()])
    dataset = datasets.CIFAR10("./data", train=True, download=True, transform=transform)
    
    save_dir = f"{BASE_PATH}/images_real_cifar10/"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"正在保存 {num_images} 张真实CIFAR-10图像...")
    for i in tqdm(range(num_images)):
        img, _ = dataset[i]
        img_path = os.path.join(save_dir, f"{i:04d}.png")
        utils.save_image(img, img_path)

# -------------------------------
# 8. 使用专业包计算FID和IS
# -------------------------------
def calculate_fid_pytorch_fid(real_path, fake_path, device='cuda'):
    """使用pytorch-fid包计算FID"""
    if not PYTORCH_FID_AVAILABLE:
        print("pytorch-fid 不可用，跳过计算")
        return None
    
    try:
        print("使用pytorch-fid计算FID...")
        fid_value = fid_score.calculate_fid_given_paths([real_path, fake_path], 
                                                       batch_size=50, 
                                                       device=device, 
                                                       dims=2048)
        return fid_value
    except Exception as e:
        print(f"pytorch-fid计算失败: {e}")
        return None

def calculate_metrics_torchmetrics(real_path, fake_path, device='cuda'):
    """使用torchmetrics计算FID和IS"""
    if not TORCHMETRICS_AVAILABLE:
        print("torchmetrics 不可用，跳过计算")
        return None, None, None

    try:
        # 数据预处理
        transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        real_dataset = ImageFolderDataset(real_path, transform=transform)
        fake_dataset = ImageFolderDataset(fake_path, transform=transform)
        
        real_loader = DataLoader(real_dataset, batch_size=32, shuffle=False)
        fake_loader = DataLoader(fake_dataset, batch_size=32, shuffle=False)
        
        # 初始化指标
        fid = FrechetInceptionDistance(feature=2048, normalize=True).to(device)
        inception_score = InceptionScore(normalize=True).to(device)
        
        print("使用torchmetrics计算指标...")
        
        # 更新FID
        for real_batch in tqdm(real_loader, desc="处理真实图像"):
            real_batch = real_batch.to(device)
            # 确保图像是RGB格式并且在正确范围内
            if real_batch.shape[1] == 1:
                real_batch = real_batch.repeat(1, 3, 1, 1)
            real_batch = (real_batch + 1) / 2  # 转换到[0,1]
            real_batch = torch.clamp(real_batch, 0, 1)
            fid.update(real_batch, real=True)
        
        for fake_batch in tqdm(fake_loader, desc="处理生成图像"):
            fake_batch = fake_batch.to(device)
            if fake_batch.shape[1] == 1:
                fake_batch = fake_batch.repeat(1, 3, 1, 1)
            fake_batch = (fake_batch + 1) / 2
            fake_batch = torch.clamp(fake_batch, 0, 1)
            fid.update(fake_batch, real=False)
            
            # 更新IS
            inception_score.update(fake_batch)
        
        # 计算最终分数
        fid_score = fid.compute().item()
        is_mean, is_std = inception_score.compute()
        is_mean, is_std = is_mean.item(), is_std.item()
        
        return fid_score, is_mean, is_std
        
    except Exception as e:
        print(f"torchmetrics计算失败: {e}")
        return None, None, None

# -------------------------------
# 9. 图像数据集类
# -------------------------------
class ImageFolderDataset(Dataset):
    def __init__(self, root, transform=None):
        self.root = root
        self.transform = transform
        self.images = [f for f in os.listdir(root) if f.endswith(('.png', '.jpg', '.jpeg'))]
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.root, self.images[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# -------------------------------
# 10. 自定义IS和FID实现（备用）
# -------------------------------
def compute_inception_score_custom(images, device='cuda', batch_size=32, splits=10):
    """自定义IS计算（当专业包不可用时使用）"""
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()
    
    up = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)
    
    def get_pred(x):
        if x.shape[1] == 1:
            x = x.repeat(1, 3, 1, 1)
        x = up(x)
        x = inception_model(x)
        return torch.nn.functional.softmax(x, dim=1).data.cpu().numpy()

    dataloader = DataLoader(images, batch_size=batch_size, shuffle=False)
    preds = []
    
    print("计算Inception Score (自定义实现)...")
    with torch.no_grad():
        for batch in tqdm(dataloader):
            batch = batch.to(device)
            pred = get_pred(batch)
            preds.append(pred)
    
    preds = np.concatenate(preds, axis=0)
    
    scores = []
    N = preds.shape[0]
    for i in range(splits):
        part = preds[i * (N // splits): (i + 1) * (N // splits), :]
        py = np.mean(part, axis=0)
        scores.append([np.sum(p * (np.log(p + 1e-10) - np.log(py + 1e-10))) for p in part])
    
    scores = np.concatenate(scores)
    is_mean = np.exp(np.mean(scores))
    is_std = np.exp(np.std(scores))
    
    return is_mean, is_std

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    """计算Fréchet距离"""
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)
    
    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)
    
    diff = mu1 - mu2
    
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))
    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real
    
    tr_covmean = np.trace(covmean)
    
    return (diff.dot(diff) + np.trace(sigma1) + 
            np.trace(sigma2) - 2 * tr_covmean)

def compute_fid_score_custom(real_images, fake_images, device='cuda', batch_size=32):
    """自定义FID计算"""
    inception_model = inception_v3(pretrained=True, transform_input=False).to(device)
    inception_model.eval()
    
    inception_model.fc = nn.Identity()
    
    up = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)
    
    def get_activations(dataset):
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
        activations = []
        
        with torch.no_grad():
            for batch in tqdm(dataloader):
                batch = batch.to(device)
                if batch.shape[1] == 1:
                    batch = batch.repeat(1, 3, 1, 1)
                batch = up(batch)
                pred = inception_model(batch).cpu().numpy()
                activations.append(pred)
        
        return np.concatenate(activations, axis=0)
    
    print("计算真实图像的特征 (自定义实现)...")
    real_activations = get_activations(real_images)
    print("计算生成图像的特征 (自定义实现)...")
    fake_activations = get_activations(fake_images)
    
    mu_real = np.mean(real_activations, axis=0)
    sigma_real = np.cov(real_activations, rowvar=False)
    
    mu_fake = np.mean(fake_activations, axis=0)
    sigma_fake = np.cov(fake_activations, rowvar=False)
    
    fid_score = calculate_frechet_distance(mu_real, sigma_real, mu_fake, sigma_fake)
    
    return fid_score

# -------------------------------
# 11. 综合评估函数
# -------------------------------
def evaluate_model(fake_dir, real_dir, model_name, device='cuda'):
    """综合评估模型"""
    print(f"\n{'='*50}")
    print(f"评估 {model_name} 模型")
    print(f"{'='*50}")
    
    results = {}
    
    # 1. 尝试使用pytorch-fid计算FID
    fid_pytorch = calculate_fid_pytorch_fid(real_dir, fake_dir, device)
    if fid_pytorch is not None:
        results['FID_pytorch'] = fid_pytorch
        print(f"FID (pytorch-fid): {fid_pytorch:.4f}")
    
    # 2. 尝试使用torchmetrics计算FID和IS
    fid_tm, is_mean_tm, is_std_tm = calculate_metrics_torchmetrics(real_dir, fake_dir, device)
    if fid_tm is not None:
        results['FID_torchmetrics'] = fid_tm
        results['IS_mean_torchmetrics'] = is_mean_tm
        results['IS_std_torchmetrics'] = is_std_tm
        print(f"FID (torchmetrics): {fid_tm:.4f}")
        print(f"IS (torchmetrics): {is_mean_tm:.4f} ± {is_std_tm:.4f}")
    
    # 3. 如果专业包都不可用，使用自定义实现
    if not results:
        print("使用自定义实现计算指标...")
        transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        fake_dataset = ImageFolderDataset(fake_dir, transform=transform)
        real_dataset = ImageFolderDataset(real_dir, transform=transform)
        
        # 计算IS
        is_mean_custom, is_std_custom = compute_inception_score_custom(fake_dataset, device=device)
        results['IS_mean_custom'] = is_mean_custom
        results['IS_std_custom'] = is_std_custom
        
        # 计算FID
        fid_custom = compute_fid_score_custom(real_dataset, fake_dataset, device=device)
        results['FID_custom'] = fid_custom
        
        print(f"IS (自定义): {is_mean_custom:.4f} ± {is_std_custom:.4f}")
        print(f"FID (自定义): {fid_custom:.4f}")
    
    return results

# -------------------------------
# 12. 绘制损失曲线
# -------------------------------
def plot_losses(G_losses, D_losses, model_name):
    plt.figure(figsize=(10, 5))
    plt.plot(G_losses, label='Generator Loss')
    plt.plot(D_losses, label='Discriminator Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training Losses - {model_name}')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{BASE_PATH}/losses_{model_name}.png')
    plt.show()

# -------------------------------
# 13. 执行训练和评估
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"使用设备: {device}")
print(f"基础路径: {BASE_PATH}")

# 创建基础目录
os.makedirs(BASE_PATH, exist_ok=True)

# 保存真实CIFAR-10图像
print("保存真实CIFAR-10图像...")
save_real_cifar10_images(num_images=1000)

# 训练两个模型
print("\n训练使用Sigmoid激活函数的GAN...")
generator_sigmoid = train_cifar10_gan(epochs=50, use_vsig=False, model_name="sigmoid")

print("\n训练使用Vsig激活函数的GAN...")  
generator_vsig = train_cifar10_gan(epochs=50, use_vsig=True, model_name="vsig")

# 生成图像用于评估
print("\n生成图像用于评估...")
save_generated_images(generator_sigmoid, model_name="sigmoid", num_images=1000)
save_generated_images(generator_vsig, model_name="vsig", num_images=1000)

# 评估模型
results_sigmoid = evaluate_model(
    f"{BASE_PATH}/images_fake_sigmoid/", 
    f"{BASE_PATH}/images_real_cifar10/", 
    "Sigmoid", device=device)

results_vsig = evaluate_model(
    f"{BASE_PATH}/images_fake_vsig/", 
    f"{BASE_PATH}/images_real_cifar10/", 
    "Vsig", device=device)

# 输出最终对比结果
print("\n" + "="*60)
print("最终结果对比:")
print("="*60)

for metric in results_sigmoid.keys():
    if metric in results_vsig:
        print(f"{metric}:")
        print(f"  Sigmoid: {results_sigmoid[metric]:.4f}")
        print(f"  Vsig:    {results_vsig[metric]:.4f}")
        print()
# Out:
# 检查已下载的模型文件...
# pytorch-fid文件存在: 91.2 MB
# torch-fidelity文件存在: 91.2 MB
# pytorch-fid 状态: 可用
# torchmetrics 状态: 可用
# 使用设备: cuda
# 基础路径: D:/PRE2023 2025
# 保存真实CIFAR-10图像...
# Files already downloaded and verified
# 正在保存 1000 张真实CIFAR-10图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 987.84it/s]
# 训练使用Sigmoid激活函数的GAN...
# Using device: cuda
# Files already downloaded and verified
# 开始训练 sigmoid 模型...
# [sigmoid] Epoch 1/50 | D_loss: 0.9236 | G_loss: 3.1407
# [sigmoid] Epoch 2/50 | D_loss: 1.0173 | G_loss: 2.2455
# [sigmoid] Epoch 3/50 | D_loss: 0.9496 | G_loss: 2.1848
# [sigmoid] Epoch 4/50 | D_loss: 0.9872 | G_loss: 1.8685
# [sigmoid] Epoch 5/50 | D_loss: 0.9935 | G_loss: 1.8907
# [sigmoid] Epoch 6/50 | D_loss: 1.0480 | G_loss: 1.7209
# [sigmoid] Epoch 7/50 | D_loss: 1.0744 | G_loss: 1.6390
# [sigmoid] Epoch 8/50 | D_loss: 1.1050 | G_loss: 1.5728
# [sigmoid] Epoch 9/50 | D_loss: 1.0772 | G_loss: 1.5472
# [sigmoid] Epoch 10/50 | D_loss: 1.0909 | G_loss: 1.5256
# [sigmoid] Epoch 11/50 | D_loss: 1.0990 | G_loss: 1.5332
# [sigmoid] Epoch 12/50 | D_loss: 1.0701 | G_loss: 1.5344
# [sigmoid] Epoch 13/50 | D_loss: 1.1086 | G_loss: 1.4971
# [sigmoid] Epoch 14/50 | D_loss: 1.0721 | G_loss: 1.4602
# [sigmoid] Epoch 15/50 | D_loss: 1.1314 | G_loss: 1.4067
# [sigmoid] Epoch 16/50 | D_loss: 1.1137 | G_loss: 1.3817
# [sigmoid] Epoch 17/50 | D_loss: 1.1204 | G_loss: 1.3948
# [sigmoid] Epoch 18/50 | D_loss: 1.1418 | G_loss: 1.3795
# [sigmoid] Epoch 19/50 | D_loss: 1.1173 | G_loss: 1.3583
# [sigmoid] Epoch 20/50 | D_loss: 1.1029 | G_loss: 1.4164
# [sigmoid] Epoch 21/50 | D_loss: 1.1431 | G_loss: 1.3890
# [sigmoid] Epoch 22/50 | D_loss: 1.1347 | G_loss: 1.3732
# [sigmoid] Epoch 23/50 | D_loss: 1.1096 | G_loss: 1.4078
# [sigmoid] Epoch 24/50 | D_loss: 1.1164 | G_loss: 1.3935
# [sigmoid] Epoch 25/50 | D_loss: 1.1105 | G_loss: 1.3898
# [sigmoid] Epoch 26/50 | D_loss: 1.1492 | G_loss: 1.3860
# [sigmoid] Epoch 27/50 | D_loss: 1.1188 | G_loss: 1.3854
# [sigmoid] Epoch 28/50 | D_loss: 1.1001 | G_loss: 1.4107
# [sigmoid] Epoch 29/50 | D_loss: 1.1090 | G_loss: 1.4161
# [sigmoid] Epoch 30/50 | D_loss: 1.1330 | G_loss: 1.4046
# [sigmoid] Epoch 31/50 | D_loss: 1.1085 | G_loss: 1.3831
# [sigmoid] Epoch 32/50 | D_loss: 1.0889 | G_loss: 1.4134
# [sigmoid] Epoch 33/50 | D_loss: 1.1098 | G_loss: 1.4081
# [sigmoid] Epoch 34/50 | D_loss: 1.0817 | G_loss: 1.4394
# [sigmoid] Epoch 35/50 | D_loss: 1.0963 | G_loss: 1.4486
# [sigmoid] Epoch 36/50 | D_loss: 1.0778 | G_loss: 1.4533
# [sigmoid] Epoch 37/50 | D_loss: 1.0661 | G_loss: 1.4826
# [sigmoid] Epoch 38/50 | D_loss: 1.0712 | G_loss: 1.4869
# [sigmoid] Epoch 39/50 | D_loss: 1.0552 | G_loss: 1.4802
# [sigmoid] Epoch 40/50 | D_loss: 1.0656 | G_loss: 1.5120
# [sigmoid] Epoch 41/50 | D_loss: 1.0682 | G_loss: 1.5011
# [sigmoid] Epoch 42/50 | D_loss: 1.0469 | G_loss: 1.5063
# [sigmoid] Epoch 43/50 | D_loss: 1.1047 | G_loss: 1.4747
# [sigmoid] Epoch 44/50 | D_loss: 1.0208 | G_loss: 1.5294
# [sigmoid] Epoch 45/50 | D_loss: 1.0486 | G_loss: 1.5234
# [sigmoid] Epoch 46/50 | D_loss: 1.0401 | G_loss: 1.5599
# [sigmoid] Epoch 47/50 | D_loss: 1.0460 | G_loss: 1.5333
# [sigmoid] Epoch 48/50 | D_loss: 1.0522 | G_loss: 1.5518
# [sigmoid] Epoch 49/50 | D_loss: 1.0198 | G_loss: 1.5657
# [sigmoid] Epoch 50/50 | D_loss: 1.0496 | G_loss: 1.5528
# 训练使用Vsig激活函数的GAN...
# Using device: cuda
# Files already downloaded and verified
# 开始训练 vsig 模型...
# [vsig] Epoch 1/50 | D_loss: 0.9831 | G_loss: 2.2188 | Sigma: 1.1788
# [vsig] Epoch 2/50 | D_loss: 1.1034 | G_loss: 1.5999 | Sigma: 1.1292
# [vsig] Epoch 3/50 | D_loss: 1.0851 | G_loss: 1.6291 | Sigma: 1.0874
# [vsig] Epoch 4/50 | D_loss: 1.0307 | G_loss: 1.6143 | Sigma: 1.0278
# [vsig] Epoch 5/50 | D_loss: 1.0939 | G_loss: 1.4991 | Sigma: 0.9837
# [vsig] Epoch 6/50 | D_loss: 1.1364 | G_loss: 1.4512 | Sigma: 0.9551
# [vsig] Epoch 7/50 | D_loss: 1.1660 | G_loss: 1.4205 | Sigma: 0.9312
# [vsig] Epoch 8/50 | D_loss: 1.1659 | G_loss: 1.3737 | Sigma: 0.9056
# [vsig] Epoch 9/50 | D_loss: 1.1627 | G_loss: 1.3606 | Sigma: 0.8753
# [vsig] Epoch 10/50 | D_loss: 1.1681 | G_loss: 1.3187 | Sigma: 0.8498
# [vsig] Epoch 11/50 | D_loss: 1.1571 | G_loss: 1.3375 | Sigma: 0.8220
# [vsig] Epoch 12/50 | D_loss: 1.1390 | G_loss: 1.3416 | Sigma: 0.7893
# [vsig] Epoch 13/50 | D_loss: 1.1343 | G_loss: 1.3409 | Sigma: 0.7585
# [vsig] Epoch 14/50 | D_loss: 1.1503 | G_loss: 1.3401 | Sigma: 0.7341
# [vsig] Epoch 15/50 | D_loss: 1.1653 | G_loss: 1.3182 | Sigma: 0.7205
# [vsig] Epoch 16/50 | D_loss: 1.1692 | G_loss: 1.3040 | Sigma: 0.7056
# [vsig] Epoch 17/50 | D_loss: 1.1638 | G_loss: 1.3056 | Sigma: 0.6888
# [vsig] Epoch 18/50 | D_loss: 1.1660 | G_loss: 1.2976 | Sigma: 0.6737
# [vsig] Epoch 19/50 | D_loss: 1.1607 | G_loss: 1.3112 | Sigma: 0.6589
# [vsig] Epoch 20/50 | D_loss: 1.1550 | G_loss: 1.3312 | Sigma: 0.6429
# [vsig] Epoch 21/50 | D_loss: 1.1606 | G_loss: 1.3165 | Sigma: 0.6295
# [vsig] Epoch 22/50 | D_loss: 1.1605 | G_loss: 1.3270 | Sigma: 0.6187
# [vsig] Epoch 23/50 | D_loss: 1.1522 | G_loss: 1.3386 | Sigma: 0.6055
# [vsig] Epoch 24/50 | D_loss: 1.1545 | G_loss: 1.3316 | Sigma: 0.5959
# [vsig] Epoch 25/50 | D_loss: 1.1543 | G_loss: 1.3590 | Sigma: 0.5887
# [vsig] Epoch 26/50 | D_loss: 1.1408 | G_loss: 1.3566 | Sigma: 0.5752
# [vsig] Epoch 27/50 | D_loss: 1.1493 | G_loss: 1.3632 | Sigma: 0.5696
# [vsig] Epoch 28/50 | D_loss: 1.1240 | G_loss: 1.3768 | Sigma: 0.5542
# [vsig] Epoch 29/50 | D_loss: 1.1264 | G_loss: 1.3762 | Sigma: 0.5422
# [vsig] Epoch 30/50 | D_loss: 1.1157 | G_loss: 1.4054 | Sigma: 0.5280
# [vsig] Epoch 31/50 | D_loss: 1.1136 | G_loss: 1.4166 | Sigma: 0.5159
# [vsig] Epoch 32/50 | D_loss: 1.1098 | G_loss: 1.4391 | Sigma: 0.5044
# [vsig] Epoch 33/50 | D_loss: 1.1169 | G_loss: 1.4231 | Sigma: 0.4990
# [vsig] Epoch 34/50 | D_loss: 1.0939 | G_loss: 1.4589 | Sigma: 0.4871
# [vsig] Epoch 35/50 | D_loss: 1.0931 | G_loss: 1.4586 | Sigma: 0.4762
# [vsig] Epoch 36/50 | D_loss: 1.0902 | G_loss: 1.4773 | Sigma: 0.4670
# [vsig] Epoch 37/50 | D_loss: 1.0720 | G_loss: 1.4991 | Sigma: 0.4538
# [vsig] Epoch 38/50 | D_loss: 1.0910 | G_loss: 1.4913 | Sigma: 0.4495
# [vsig] Epoch 39/50 | D_loss: 1.0761 | G_loss: 1.5141 | Sigma: 0.4423
# [vsig] Epoch 40/50 | D_loss: 1.0692 | G_loss: 1.5219 | Sigma: 0.4313
# [vsig] Epoch 41/50 | D_loss: 1.0623 | G_loss: 1.5294 | Sigma: 0.4223
# [vsig] Epoch 42/50 | D_loss: 1.0805 | G_loss: 1.5284 | Sigma: 0.4235
# [vsig] Epoch 43/50 | D_loss: 1.0480 | G_loss: 1.5474 | Sigma: 0.4098
# [vsig] Epoch 44/50 | D_loss: 1.0532 | G_loss: 1.5732 | Sigma: 0.4032
# [vsig] Epoch 45/50 | D_loss: 1.0548 | G_loss: 1.5622 | Sigma: 0.3960
# [vsig] Epoch 46/50 | D_loss: 1.0396 | G_loss: 1.5982 | Sigma: 0.3866
# [vsig] Epoch 47/50 | D_loss: 1.0696 | G_loss: 1.5825 | Sigma: 0.3908
# [vsig] Epoch 48/50 | D_loss: 1.0382 | G_loss: 1.5867 | Sigma: 0.3819
# [vsig] Epoch 49/50 | D_loss: 1.0251 | G_loss: 1.6144 | Sigma: 0.3727
# [vsig] Epoch 50/50 | D_loss: 1.0395 | G_loss: 1.6127 | Sigma: 0.3676
# Sigma值变化图已保存到: D:/PRE2023 2025/sigma_evolution_vsig.png
# Sigma值变化已保存到: D:/PRE2023 2025/sigma_values_vsig.npy
#
# 生成图像用于评估...
# 正在保存 1000 张生成图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 432.11it/s]
# 正在保存 1000 张生成图像...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 402.66it/s]
# ==================================================
# 评估 Sigmoid 模型
# ==================================================
# 使用pytorch-fid计算FID...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:11<00:00,  1.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# FID (pytorch-fid): 83.1565
# 使用torchmetrics计算指标...
# 处理真实图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:03<00:00,  8.43it/s]
# 处理生成图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:05<00:00,  6.17it/s]
# FID (torchmetrics): 82.5898
# IS (torchmetrics): 5.4527 ± 0.3640
#
# ==================================================
# 评估 Vsig 模型
# ==================================================
# 使用pytorch-fid计算FID...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:08<00:00,  2.49it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:11<00:00,  1.68it/s]
# FID (pytorch-fid): 82.3954
# 使用torchmetrics计算指标...
# 处理真实图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:03<00:00,  8.59it/s]
# 处理生成图像: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:04<00:00,  6.40it/s]
# FID (torchmetrics): 81.6192
# IS (torchmetrics): 5.6433 ± 0.3356
#
# ============================================================
# 最终结果对比:
# ============================================================
# FID_pytorch:
#   Sigmoid: 83.1565
#   Vsig:    82.3954
#
# FID_torchmetrics:
#   Sigmoid: 82.5898
#   Vsig:    81.6192
#
# IS_mean_torchmetrics:
#   Sigmoid: 5.4527
#   Vsig:    5.6433
#
# IS_std_torchmetrics:
#   Sigmoid: 0.3640
#   Vsig:    0.3356
